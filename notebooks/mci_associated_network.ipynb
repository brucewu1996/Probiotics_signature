# %%
import numpy as np
import pandas as pd
import seaborn as sns
import re
import matplotlib.pyplot as plt
import networkx as nx
import markov_clustering as mc
import matplotlib

# %%
output_path = '/home/bruce1996/data/pr/0809/'

# %%
metaphlan_output = "/home/bruce1996/data/MCI/metaphlan_result/formated_mci_metaphlan_table.txt"
metadata = pd.read_csv('/home/bruce1996/data/MCI/metadata/MCI_label.txt',sep = '\t',index_col=0)
meta_df = pd.read_csv(metaphlan_output,sep = '\t',index_col=0)
meta_df.columns = [x.split('_')[0] for x in meta_df.columns]

selected_df = pd.read_csv("/home/bruce1996/repo/MCI_PGD/total_selected_feature.txt",sep = '\t',header=None)
selected_s = selected_df.iloc[:,0].values
candidate_df = meta_df.loc[selected_s,:]

consensus_cluster = pd.read_csv('/home/bruce1996/data/MCI/metaphlan_result/consensus_clustering.txt',sep='\t',index_col=0)
consensus_cluster = consensus_cluster.loc[candidate_df.columns,:]

# %%
candidate_df.columns.names = ['Subject_id']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = candidate_df.T.to_numpy()
x = scaler.fit_transform(X)
candidate_std_df = pd.DataFrame(x.T,index=candidate_df.index,columns=candidate_df.columns)
lefse_df = pd.concat([consensus_cluster.T,candidate_std_df],axis=0)

# %%
lefse_df.to_csv('/home/bruce1996/data/MCI/metaphlan_result/candidate_df_consensus_cluster_for_lefse.txt',sep = '\t')

# %%
deseq_output = '/home/bruce1996/ssd/mci_deseq_res.txt'
deseq_df = pd.read_csv(deseq_output,sep='\t',index_col=0)

# %% [markdown]
# ### humann result

# %%
humann_tsea = pd.read_csv('/home/bruce1996/data/MCI/tsea/Humann-tsea-result.txt',sep='\t',index_col=0)
keep_idx = humann_tsea['Node-pseudo-F'].values  + humann_tsea['Edge-pseudo-F'].values > 0
humann_tsea = humann_tsea.loc[keep_idx,:]

# %%
cmap = plt.cm.gist_rainbow
colors = cmap(np.linspace(0., 1., 20))
matplotlib.colors.rgb2hex(colors[2])

idx = (humann_tsea['Node-pseudo-F'] < 0.05) & (humann_tsea['Edge-pseudo-F'] < 0.05)
sig_path = humann_tsea.loc[idx,:]

# %%
n = sig_path.shape[0]
cmap = plt.cm.gist_rainbow
colors = cmap(np.linspace(0., 1., n))
plt.figure(figsize=(10,8))
plt.xlim([0,0.05])
plt.ylim([0,0.05])
for i in range(n) :
    s,n,e = sig_path.iloc[i,:]
    c = matplotlib.colors.rgb2hex(colors[i])
    plt.scatter(e,n,color= c)
    plt.text(e,n,s,fontsize = 10,color = c,rotation=0,horizontalalignment='left',verticalalignment='bottom')  
plt.ylabel('Node pseudo-F p-value')
plt.xlabel('Edge pseudo-F p-value')
plt.title('Taxonomy set enrichment analysis of humann output')
plt.savefig(output_path + 'Humann-tsea-scatterplot-cross-threshold.png',dpi = 300)

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Network module

# %%
from scipy.stats import spearmanr,scoreatpercentile

###calculate z score
def zscore_dict(df,fisher_z_transform =True) :
    n = df.shape[0]
    corr_z_dict = dict()
    for col in range(n-1) :
        for row in range(col+1,n) :
            name = (df.index[col],df.index[row])
            t1 = df.iloc[col,:]
            t2 = df.iloc[row,:]
            idx = (t1 + t2) > 0
            n_sample = sum(idx)
            r,p = spearmanr(t1[idx],t2[idx])
            if fisher_z_transform :
                z = np.arctanh(r) * np.sqrt(n_sample - 3)
                corr_z_dict[name] = z
            else :
                corr_z_dict[name] = r
    return corr_z_dict

def zscore_percentile(corr_z_dict,pr) :
    z_list = list(corr_z_dict.values())
    percentile=scoreatpercentile(z_list, pr)
    return percentile

def zscore_hist(corr_z_dict,output_path,title) :

    z_list = list(corr_z_dict.values())
    df = pd.DataFrame({'z-score' : z_list})
    plt.figure(figsize=(8,5))
    sns.histplot(data = df,x = 'z-score',kde=True,stat='percent',bins=10,palette='Set2')
    plt.title(title)
    plt.savefig(output_path)

###network module
def create_corr_network(df,fisher_z_transform=True) :
    n = df.shape[0]
    corr_dict = dict()
    for col in range(n-1) :
        for row in range(col+1,n) :
            name = (df.index[col],df.index[row])
            t1 = df.iloc[col,:]
            t2 = df.iloc[row,:]
            if fisher_z_transform :
                idx = (t1 + t2) > 0
                n_sample = sum(idx)
                r,p = spearmanr(t1[idx],t2[idx])
                z = np.arctanh(r) * np.sqrt(n - 3)
                corr_dict[name] = z
            else :
                r,p = spearmanr(t1,t2)
                corr_dict[name] = r

    g = nx.Graph()
    g.add_nodes_from(df.index)
    #only add edge
    g.add_edges_from(corr_dict)
    #add z score of edge to graph object
    nx.set_edge_attributes(g,corr_dict,'weight')
    #add node attribute
    pv_lambda = lambda x : 100 * (sum(x > 0) / len(x))
    pv = list(map(pv_lambda,df.to_numpy()))
    pv_dict = dict(zip(df.index,pv))

    m_ab = df.mean(axis=1)
    mab_dict = dict(zip(df.index,m_ab))
    nx.set_node_attributes(g,pv_dict,name='Prevalence')
    nx.set_node_attributes(g,mab_dict,name='Mean abundance')

    return g


def filter_corr_network(g,threshold,pos_only=False,remove_node=True,p_color = '#66c2a5',n_color='#fc8d62'):
    g_c = g.copy()
    color_dict = dict()
    #p_color = ImageColor.getcolor(p_color, "RGB")
    #n_color = ImageColor.getcolor(n_color, "RGB")
    for n1,n2,w in g_c.edges(data=True) :
        if pos_only :
            if w['weight'] < threshold :
                g.remove_edge(n1,n2)
            else :
                #add color attribute
                if w['weight'] > 0 :
                    color_dict[(n1,n2)] = p_color
                else :
                    color_dict[(n1,n2)] = n_color
        else :
            if abs(w['weight']) < threshold :
                g.remove_edge(n1,n2)
            else :
                #add color attribute
                if w['weight'] > 0 :
                    color_dict[(n1,n2)] = p_color
                else :
                    color_dict[(n1,n2)] = n_color
    nx.set_edge_attributes(g,color_dict,name='Color')
    #remove node degree = 1
    if remove_node :
        g_c = g.copy()
        for n,d in g_c.degree :
            if d < 2 :
                g.remove_node(n)

def sort_taxonomy_for_tsea(df) :
    n = df.shape[0]
    corr_z_dict = dict()
    for col in range(n-1) :
        for row in range(col+1,n) :
            name = (df.index[col],df.index[row])
            t1 = df.iloc[col,:]
            t2 = df.iloc[row,:]
            idx = (t1 + t2) > 0
            r,p = spearmanr(t1[idx],t2[idx])
            z = np.arctanh(r)
            corr_z_dict[name] = z
    df = pd.DataFrame({'Name' : corr_z_dict.keys(),'z-score' : corr_z_dict.values()}).sort_values(by='z-score',ascending=False)
    return list(df['Name'].values)

def subgraph(g,candidate,attr) :
    g_c = g.copy()
    cl = list(nx.get_node_attributes(g,attr).values())
    nl = list(g.nodes())
    for i in range(len(cl)) :
        if cl[i] != candidate :
            g_c.remove_node(nl[i])
    return g_c

# %% [markdown]
# ### MCL module

# %%
### mcl module
def mcl_clustering(G) :

    matrix = nx.to_scipy_sparse_matrix(G,dtype=np.float32)
    result = mc.run_mcl(matrix)           
    clusters = mc.get_clusters(result)

    cluster_dict = dict()
    color_dict = dict()
    #set color for mcl clusters
    cmap = plt.cm.gist_rainbow
    n_cluster = len(clusters)
    colors = cmap(np.linspace(0., 1., n_cluster))

    node_list = list(G.nodes().keys())
    n_c = 0
    for i in range(len(clusters)) :
        if len(clusters[i]) < 2 :
            n = node_list[clusters[i][0]]
            cluster_dict[n] = 'No cluster'
            color_dict[n] = matplotlib.colors.rgb2hex(np.array([192/255,192/255,192/255,1]))
        else :
            for j in range(len(clusters[i])) :
                n = node_list[clusters[i][j]]
                cluster_dict[n] = "Cluster " + str(n_c)
                color_dict[n] = matplotlib.colors.rgb2hex(colors[n_c])
            n_c += 1
    nx.set_node_attributes(G,cluster_dict,'Cluster')
    nx.set_node_attributes(G,color_dict,'Color')

def number_of_mcl_cluster(g) :
    cl = list(nx.get_node_attributes(g,'Cluster').values())
    nl = list(g.nodes().keys())
    degree_list = [x[1] for x in g.degree]
    df = pd.DataFrame({'Species' : nl,'Cluster' : cl,'Degree' : degree_list})
    for i in list(set(df['Cluster'])) :
        num = sum(df['Cluster'] == i)
        print('Number of node in %s : %d' % (i,num))

# %% [markdown]
# ### plot module

# %%
### plot module
def plot_corr_network(G,title,fig_output,random_layout=False,fontsize=None,figsize = (20,12)) :

    plt.figure(figsize = figsize)
    #pos = nx.spring_layout(G,k = 4 / sqrt(G.order()))
    if random_layout :
        pos = nx.random_layout(G)
    else :
        pos = nx.spring_layout(G)
    #pos = nx.multipartite_layout(G,subset_key='Cluster')
    #plot node
    node_color_list = nx.get_node_attributes(G,'Color').values()
    nx.draw_networkx_nodes(G,pos,node_color=node_color_list,alpha=0.8,node_size = [v[1] ** 2 for v in G.degree]) 
    species = list(pos.keys())
    for idx in range(len(pos)) :
        s = species[idx]
        x = pos[s][0]
        y = pos[s][1]
        if fontsize == None :
            plt.text(x,y,s,fontsize = G.degree[s],horizontalalignment='center',verticalalignment='center')  
        else :
            plt.text(x,y,s,fontsize = fontsize,horizontalalignment='center',verticalalignment='bottom')
    #plot edge
    edge_color = nx.get_edge_attributes(G,'Color').values()
    nx.draw_networkx_edges(G,pos,edge_color=edge_color)
    #plot legend
    node_cluser_list = nx.get_node_attributes(G,'Cluster').values()
    legend_dict = dict(zip(node_cluser_list,node_color_list))
    
    for cl,col in legend_dict.items() :
        plt.plot([],[],color = col,label = cl)
    
    plt.legend()
    plt.title(title,fontsize = 15)
    plt.savefig(fig_output)
    plt.show()

def degree_barplot(G,title,fig_output) :
    
    n_node = len(G.nodes())
    d_array = np.empty(n_node,dtype=int)
    n_array = np.empty(n_node,dtype=object)
    idx = 0
    for n,d in G.degree() :
        n_array[idx] = n
        d_array[idx] = d
        idx += 1
    plot_df = pd.DataFrame({'Species' : n_array,'Degree' : d_array})
    plot_df = plot_df.sort_values(by='Degree',ascending=False)
    plt.figure(figsize=(15,6))
    sns.barplot(data=plot_df,x='Species',y='Degree')
    plt.xticks(rotation=90)
    plt.title(title)
    plt.savefig(fig_output,dpi=300)

def node_scatter_plot(G,df,label,title,fig_output,xlabel,ylabel,measure='pv') :
    s = list(G.nodes)
    df = df.loc[s,:]
    if measure == 'pv' :
        pv_lambda = lambda x : 100 * ( sum(x>0) / len(x))
        x = list(map(pv_lambda,df.loc[:,label].to_numpy()))
        y = list(map(pv_lambda,df.loc[:,label==False].to_numpy()))
    elif measure == 'mab' :
        x = df.loc[:,label].mean(axis=1)
        y = df.loc[:,label == False].mean(axis=1)
    plt.scatter(x = x,y=y,c=y,cmap='rainbow')
    mi= min(min(x),min(y))
    ma = max(max(x),max(y))
    plt.plot([0,ma],[0,ma], 'r-')

    if measure == 'pv' :
        plt.xlim([mi-5,ma+5])
        plt.ylim([mi-5,ma+5])
    elif measure == 'mab' :
        plt.xlim([mi-0.05,ma+0.05])
        plt.ylim([mi-0.05,ma+0.05])
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.savefig(fig_output)
    plt.show()

def node_scatter_subplot(G,df,label,title,fig_output,xlabel,ylabel) :
    s = list(G.nodes)
    df = df.loc[s,:]
    f, (ax1, ax2) = plt.subplots(1, 2,figsize = (11,5))

    pv_lambda = lambda x : 100 * ( sum(x>0) / len(x))
    pv_x = list(map(pv_lambda,df.loc[:,label].to_numpy()))
    pv_y = list(map(pv_lambda,df.loc[:,label==False].to_numpy()))
    ab_x = df.loc[:,label].mean(axis=1)
    ab_y = df.loc[:,label == False].mean(axis=1)
    ###prevalence
    ax1.scatter(x = pv_x,y=pv_y,c=pv_y,cmap='rainbow')
    pv_mi= min(min(pv_x),min(pv_y))
    pv_ma = max(max(pv_x),max(pv_y))
    ax1.plot([0,pv_ma],[0,pv_ma], 'r-')

    ax1.set_xlim([pv_mi-5,pv_ma+5])
    ax1.set_ylim([pv_mi-5,pv_ma+5])
    ax1.set_xlabel('Prevalence in ' + xlabel)
    ax1.set_ylabel('Prevalence in ' + ylabel)
    ###mean abundance
    ax2.scatter(x = ab_x,y=ab_y,c=ab_y,cmap='rainbow')
    ab_mi= min(min(ab_x),min(ab_y))
    ab_ma = max(max(ab_x),max(ab_y))
    ax2.plot([0,ab_ma],[0,ab_ma], 'r-')
    ax2.set_xlim([ab_mi-0.05,ab_ma+0.05])
    ax2.set_ylim([ab_mi-0.05,ab_ma+0.05])
    ax2.set_xlabel('Mean abundance in ' + xlabel)
    ax2.set_ylabel('Mean abundance in ' + ylabel)
       
    f.suptitle(title)
    f.tight_layout()
    #plt.savefig(fig_output)
    plt.show()

# %% [markdown]
# ### Plot

# %%
y = np.where(metadata['Diagnosis'] == 'MCI',True,False)
mci_df = candidate_df.loc[:,y].T
normal_df = candidate_df.loc[:,~y].T
##
mci_corr_z = zscore_dict(mci_df)
mci_corr = zscore_dict(mci_df,fisher_z_transform=False)
normal_corr_z = zscore_dict(normal_df)
normal_corr = zscore_dict(normal_df,fisher_z_transform=False)

# %%
x = list(mci_corr_z.values())
y = list(normal_corr_z.values())
plt.figure(figsize=(8,5))
plt.hist(x, 20, alpha=0.5, label='MCI',density=True)
plt.hist(y, 20, alpha=0.5, label='Normal',density=True)
plt.legend(loc='upper right')
plt.title('Spearman correlation z-score distribution between MCI and normal')
plt.xlabel('z-score',fontsize=12)
plt.ylabel('Density',fontsize=12)
plt.savefig(output_path + 'spearman_corr_zscore_distribution.png',dpi = 300)
plt.show()

# %%
g = create_corr_network(network_df,fisher_z_transform=True)
filter_corr_network(g,5,pos_only=True)
mcl_clustering(g)
plot_corr_network(g,'Co-expression network for sample',output_path + 'co-expression_net_by_people_normal_only_scc_07.png',figsize = (15,8),fontsize = 10)

# %% [markdown]
# ### consensus clustering

# %%
from sklearn.preprocessing import StandardScaler

X = candidate_df.to_numpy()
scaler = StandardScaler()
x = scaler.fit_transform(X)

df = pd.DataFrame(x,index=candidate_df.index,columns=candidate_df.columns)

# %%
idx = np.where(metadata['Diagnosis'] == 'MCI',True,False)
df = df.loc[:,idx]
df.to_csv('/home/bruce1996/data/MCI/metaphlan_result/standard_candidate_table_mci_only.txt',sep='\t')

# %%
###pca 
from sklearn.decomposition import PCA,KernelPCA

plot_df = pd.read_csv('/home/bruce1996/data/MCI/metaphlan_result/consensus_clustering_mci_only.txt',sep='\t',index_col=0)
kernel = 'rbf'
pca = KernelPCA(n_components=2,kernel=kernel)
X = df.to_numpy()
pca_r = pca.fit_transform(X.T)
plot_df['PC1'] = pca_r[:,0]
plot_df['PC2'] = pca_r[:,1]

plt.figure(figsize=(8,6))
sns.scatterplot(data  = plot_df ,x = 'PC1',y='PC2',hue='cluster',palette='Set2')
if kernel == None :
    pc1_variance = round(pca.explained_variance_ratio_[0] * 100,2)
    pc2_variance = round(pca.explained_variance_ratio_[1] * 100,2)
    plt.xlabel("PC1 (" + str(pc1_variance) + ")")
    plt.ylabel("PC2 (" + str(pc2_variance) + ")")

plt.title("Kernel PCA analysis label by consensus clustering (MCI only)")
plt.legend(loc='upper right')
plt.savefig(output_path + 'mci_only_consensus_rbf_pca_with_std.png')

# %%
consensus_cluster = pd.read_csv('/home/bruce1996/data/MCI/metaphlan_result/consensus_clustering.txt',sep='\t',index_col=0)
metadata = metadata.loc[consensus_cluster.index]
cluster_df = pd.DataFrame({'Cluster' : consensus_cluster['cluster'],'Diagnosis' : metadata['Diagnosis']})
cluster_df = cluster_df.sort_values(by=['Cluster','Diagnosis'])

# %%
lefse_df = pd.read_csv('/home/bruce1996/data/MCI/metaphlan_result/lefse.res',sep='\t',index_col=0,header=None)
lefse_df.columns = ["Kruskal","Cluster",'LDA','wilconox']
lefse_df.index.name = None

# %%
idx = np.where(lefse_df['Cluster'] < 4,True,False)
lefse_s = lefse_df.loc[idx,:].sort_values(by='Cluster').index
lefse_candidate_df = candidate_df.loc[lefse_s,:]
lefse_candidate_df = lefse_candidate_df.loc[:,cluster_df.index]

# %%
idx = np.where(cluster_df['Cluster'] < 4 ,True ,False)
lefse_candidate_df = lefse_candidate_df.loc[:,idx]

# %%
idx = np.where(lefse_df['Cluster'] < 4,True,False)
lefse_df = lefse_df.loc[idx,:].sort_values(by='Cluster')
lefse_df = lefse_df.loc[lefse_candidate_df.index,:]

# %%
lefse_candidate_df.to_csv('/home/bruce1996/data/MCI/metaphlan_result/lefse_candidate.txt',sep = '\t')

# %%
cluster_df.loc[lefse_candidate_df.columns,'Cluster'].to_csv('/home/bruce1996/data/MCI/metaphlan_result/lefse_candidate_label.txt',sep = '\t')

# %%
from matplotlib import cm
from matplotlib.pyplot import gcf

cluster = cluster_df.loc[lefse_candidate_df.columns,'Cluster'].values
cluster_lut = dict(zip( set(cluster),  [cm.Set2(x) for x in range(10)] ))
col_colors = pd.Series(cluster).map(cluster_lut)

cluster2 = cluster_df.loc[lefse_candidate_df.columns,'Diagnosis'].values
cluster2_lut = {'MCI': (0.85, 0.192, 0.15000000000000002),'Normal': (0.15000000000000002, 0.8079999999999997, 0.85)}
col_colors2 = pd.Series(cluster2).map(cluster2_lut)

i = 3
idx = lefse_df['Cluster'] == i 
plot_df = lefse_candidate_df.loc[idx,:]

g = sns.clustermap(plot_df, cmap="YlGnBu",
                row_cluster=False, 
                col_cluster=False,
                col_colors=[col_colors,col_colors2],
                linewidths=0, figsize=(12,7))

for label in set(cluster):
    g.ax_col_dendrogram.bar(0, 0, color=cluster_lut[label], label=label, linewidth=0)
l1 = g.ax_col_dendrogram.legend(title='Cluster', loc="center", ncol=5, bbox_to_anchor=(0.47, 0.95), bbox_transform=gcf().transFigure)

for label in set(cluster2):
    g.ax_row_dendrogram.bar(0, 0, color=cluster2_lut[label], label=label, linewidth=0)
l2 = g.ax_row_dendrogram.legend(title='MCI only cluster', loc="center", ncol=5, bbox_to_anchor=(0.47, 0.85), bbox_transform=gcf().transFigure)

plt.savefig(output_path + 'lefse_candidate_of_consensus_cluster' + str(i) + '.png',dpi = 300,bbox_inches = 'tight')

# %%
for c in range(1,3) : 
    deseq_df = pd.read_csv('/home/bruce1996/data/MCI/metaphlan_result/lefse_deseq_cluster' + str(c) + '.txt',sep='\t',index_col=0)

    idx = lefse_df['Cluster'] == c
    plot_df = deseq_df.loc[idx,:]
    plot_df['Species'] = plot_df.index
    plot_df['baseMean'] = plot_df['baseMean'] / 100
    plt.figure(figsize=(8,5))
    sns.scatterplot(data = plot_df,x = 'log2FoldChange',y='padj',hue='Species',s=100,palette='rainbow')
    plt.legend(bbox_to_anchor=(1.6,1))
    plt.ylabel('p-value')
    plt.title("Differential expression analysis of consensus cluster " + str(c) + ' candidate species')
    plt.savefig(output_path + 'lefse_deseq_of_cluster' + str(c) + '.png',dpi = 300 , bbox_inches = 'tight')
# Out:
# /tmp/ipykernel_494705/2773971052.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plot_df['Species'] = plot_df.index
# /tmp/ipykernel_494705/2773971052.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plot_df['baseMean'] = plot_df['baseMean'] / 100
# /tmp/ipykernel_494705/2773971052.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plot_df['Species'] = plot_df.index
# /tmp/ipykernel_494705/2773971052.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plot_df['baseMean'] = plot_df['baseMean'] / 100

# %%
output_path
# Out:
# '/home/bruce1996/data/pr/0809/'

# %%
c = 3
deseq_df = pd.read_csv('/home/bruce1996/data/MCI/metaphlan_result/lefse_deseq_cluster' + str(c) + '.txt',sep='\t',index_col=0)

idx = lefse_df['Cluster'] == c
plot_df = deseq_df.loc[idx,:]
plot_df['Species'] = plot_df.index
plot_df['baseMean'] = plot_df['baseMean'] / 100
plt.figure(figsize=(8,5))
sns.scatterplot(data = plot_df,x = 'log2FoldChange',y='padj',hue='Species',s=100,palette='rainbow')
plt.legend(bbox_to_anchor=(1.5,1))
plt.ylabel('p-value')
plt.title("Differential expression analysis of consensus cluster " + str(c) + ' candidate species')
plt.savefig(output_path + 'lefse_deseq_of_cluster' + str(c) + '.png',dpi = 300 , bbox_inches = 'tight')
# Out:
# /tmp/ipykernel_494705/4191367353.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plot_df['Species'] = plot_df.index
# /tmp/ipykernel_494705/4191367353.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plot_df['baseMean'] = plot_df['baseMean'] / 100

# %%
from matplotlib import cm
from matplotlib.pyplot import gcf

cluster = cluster_df.loc[lefse_candidate_df.columns,'Cluster'].values
cluster_lut = dict(zip( set(cluster),  [cm.Set2(x) for x in range(10)] ))
col_colors = pd.Series(cluster).map(cluster_lut)

cluster2 = cluster_df.loc[lefse_candidate_df.columns,'Diagnosis'].values
cluster2_lut = {'MCI': (0.85, 0.192, 0.15000000000000002),'Normal': (0.15000000000000002, 0.8079999999999997, 0.85)}
col_colors2 = pd.Series(cluster2).map(cluster2_lut)

candidate = lefse_df['Cluster'].values
candidate_lut = dict(zip(set(candidate),[cm.Set2(x) for x in range(10)]))
row_colors = pd.Series(candidate).map(candidate_lut)

plot_df = lefse_candidate_df

g = sns.clustermap(plot_df, cmap="YlGnBu",
                row_cluster=False, 
                col_cluster=False,
                col_colors=[col_colors,col_colors2],
                row_colors=[row_colors],
                linewidths=0, figsize=(12,10))

for label in set(cluster):
    g.ax_col_dendrogram.bar(0, 0, color=cluster_lut[label], label=label, linewidth=0)
l1 = g.ax_col_dendrogram.legend(title='Cluster', loc="center", ncol=5, bbox_to_anchor=(0.47, 0.95), bbox_transform=gcf().transFigure)

for label in set(cluster2):
    g.ax_row_dendrogram.bar(0, 0, color=cluster2_lut[label], label=label, linewidth=0)
l2 = g.ax_row_dendrogram.legend(title='MCI only cluster', loc="center", ncol=5, bbox_to_anchor=(0.47, 0.85), bbox_transform=gcf().transFigure)

plt.savefig(output_path + 'lefse_candidate_of_consensus_cluster.png',dpi = 300,bbox_inches = 'tight')

# %%
from matplotlib import cm
from matplotlib.pyplot import gcf

cluster = consensus_cluster['cluster'].values
cluster_lut = dict(zip( set(cluster),  [cm.Set2(x) for x in range(10)] ))
col_colors = pd.Series(cluster).map(cluster_lut)

diagnosis = metadata['Diagnosis'].values
lut = dict(zip( ['MCI','Normal'], sns.hls_palette(len(set(diagnosis)),l=0.5, s=0.8)   ))
row_colors = pd.Series(diagnosis).map(lut)

plot_df = candidate_df

g = sns.clustermap(plot_df, cmap="YlGnBu",
                row_cluster=False, 
                col_cluster=False,
                col_colors=[col_colors,row_colors],
                linewidths=0, figsize=(12,10 ))

for label in set(cluster):
    g.ax_col_dendrogram.bar(0, 0, color=cluster_lut[label], label=label, linewidth=0)
l1 = g.ax_col_dendrogram.legend(title='Cluster', loc="center", ncol=5, bbox_to_anchor=(0.47, 0.9), bbox_transform=gcf().transFigure)
plt.savefig(output_path + 'consensus_clustering_heatmap_by_candidate_species_sort_by_diagnosis.png',dpi = 300,bbox_inches = 'tight')

# %% [markdown]
# ### TSEA

# %%
from GSEA import taxonomy_enrich_analysis,enrich_score,permutation
###pesudo code
tsea_output =  '/home/bruce1996/data/MCI/tsea/'
deseq_output = '/home/bruce1996/ssd/mci_deseq_res.txt'
deseq_df = pd.read_csv(deseq_output,sep='\t',index_col=0).sort_values(by='log2FoldChange',ascending=False)

tsea = taxonomy_enrich_analysis(deseq_output=deseq_df,metaphlan_output=meta_df,humann_index=None,graph=g,taxonomy=None)
node_df = tsea.TSEA(mode='Node',sorted=False).sort_values(by='Pathway')
edge_df = tsea.TSEA(mode='Edge',sorted=False).sort_values(by='Pathway')

df = pd.DataFrame({'Name' : node_df['Pathway'],'Node-pseudo-F' : node_df['p-value'],'Edge-pseudo-F' : edge_df['p-value']})
#df.to_csv(tsea_output + 'overall_positive_corr_tsea_result.txt',sep='\t')
# Out:
# taxonomy list length : 410
# Calculate enrichment score of 1 / 10  pathway : Cluster 1
# TSEA of pathway : Cluster 1 cost 0.60 s
# Calculate enrichment score of 2 / 10  pathway : Cluster 0
# TSEA of pathway : Cluster 0 cost 0.01 s
# Calculate enrichment score of 3 / 10  pathway : Cluster 9
# TSEA of pathway : Cluster 9 cost 0.01 s
# Calculate enrichment score of 4 / 10  pathway : Cluster 3
# TSEA of pathway : Cluster 3 cost 0.01 s
# Calculate enrichment score of 5 / 10  pathway : Cluster 5
# TSEA of pathway : Cluster 5 cost 0.01 s
# Calculate enrichment score of 6 / 10  pathway : Cluster 8
# TSEA of pathway : Cluster 8 cost 0.01 s
# Calculate enrichment score of 7 / 10  pathway : Cluster 7
# TSEA of pathway : Cluster 7 cost 0.01 s
# Calculate enrichment score of 8 / 10  pathway : Cluster 4
# TSEA of pathway : Cluster 4 cost 0.01 s
# Calculate enrichment score of 9 / 10  pathway : Cluster 2
# TSEA of pathway : Cluster 2 cost 0.01 s
# Calculate enrichment score of 10 / 10  pathway : Cluster 6
# TSEA of pathway : Cluster 6 cost 0.01 s
# /home/bruce1996/repo/Microbiome_health_indicator/GSEA.py:110: RuntimeWarning: divide by zero encountered in arctanh
#   z = np.arctanh(r)
# taxonomy list length : 83845
# Calculate enrichment score of 1 / 10  pathway : Cluster 1
# TSEA of pathway : Cluster 1 cost 2.00 s
# Calculate enrichment score of 2 / 10  pathway : Cluster 0
# TSEA of pathway : Cluster 0 cost 2.01 s
# Calculate enrichment score of 3 / 10  pathway : Cluster 9
# TSEA of pathway : Cluster 9 cost 2.01 s
# Calculate enrichment score of 4 / 10  pathway : Cluster 3
# TSEA of pathway : Cluster 3 cost 2.00 s
# Calculate enrichment score of 5 / 10  pathway : Cluster 5
# TSEA of pathway : Cluster 5 cost 2.00 s
# Calculate enrichment score of 6 / 10  pathway : Cluster 8
# TSEA of pathway : Cluster 8 cost 2.01 s
# Calculate enrichment score of 7 / 10  pathway : Cluster 7
# TSEA of pathway : Cluster 7 cost 2.00 s
# Calculate enrichment score of 8 / 10  pathway : Cluster 4
# TSEA of pathway : Cluster 4 cost 2.01 s
# Calculate enrichment score of 9 / 10  pathway : Cluster 2
# TSEA of pathway : Cluster 2 cost 2.00 s
# Calculate enrichment score of 10 / 10  pathway : Cluster 6
# TSEA of pathway : Cluster 6 cost 2.00 s

# %%
nx.get_node_attributes(g,'Cluster')
cluster_list = list(set(nx.get_node_attributes(g,'Cluster').values()))
cluster_list.remove('No cluster')
for c in cluster_list :
    g_sub = subgraph(g,attr='Cluster',candidate=c)
    if len(g_sub.node()) < 10 :
        pass
    else :
        represent_s,max_degree = sorted(g.degree, key=lambda x: x[1], reverse=True)[0]
        title = 'Co-expression network for' + ' ' + c + ' ' + represent_s
        file_name = output_path + 'co-expression-network' + '-' + represent_s + '.png'
        plot_corr_network(g_sub,title,file_name,figsize = (15,8),fontsize=12)
        node_scatter_subplot(g_sub,candidate_df,l,'Cluster 0 (Streptococcus) ',output_path + 'tmp.png','MCI','normal')

# %% [markdown]
# ### main function

# %%
from GSEA import taxonomy_enrich_analysis,enrich_score,permutation

def main() :
    
    tsea_output =  '/home/bruce1996/data/MCI/tsea/'
    output_path = '/home/bruce1996/data/pr/0711/'
    deseq_output = '/home/bruce1996/ssd/mci_deseq_res.txt'
    deseq_df = pd.read_csv(deseq_output,sep='\t',index_col=0)
    metaphlan_output = "/home/bruce1996/nvme2/mci_for_adlasso/data/MCI_species_relative_abundance.txt"
    meta_df = pd.read_csv(metaphlan_output,sep = '\t',index_col=0)
    metadata = pd.read_csv('/home/bruce1996/nvme2/mci_for_adlasso/data/MCI_sample_diagnosis.csv',sep = '\t',index_col=0)
    diagnosis_idx = np.where(metadata['Diagnosis'] == 'MCI',True,False)
    ### candidate species
    selected_df = pd.read_csv('/home/bruce1996/nvme2/mci_for_adlasso/MCI/selected_feature.txt',sep = '\t',header=None)
    selected_s = selected_df.iloc[:,0].values
    candidate_df = meta_df.loc[selected_s,:]

    condition = ['Overall','MCI','Normal']
    percentile = 90
    #node_num_dict = {'Overall' : 10,'MCI' : 5,'Normal' : 5}

    for con in condition :
        
        if con == 'Overall' :
            metaphlan = meta_df
            candidate = candidate_df
        elif con == 'MCI' :
            metaphlan = meta_df.loc[:,diagnosis_idx]
            candidate = candidate_df.loc[:,diagnosis_idx]
        elif con == 'Normal' :
            metaphlan = meta_df.loc[:,diagnosis_idx == False]
            candidate = candidate_df.loc[:,diagnosis_idx == False]

        g = create_corr_network(candidate)
        zscore_dict = nx.get_edge_attributes(g,'weight')
        percentile_threshold = zscore_percentile(zscore_dict,percentile)
        filter_corr_network(g,percentile_threshold,pos_only=True)
        mcl_clustering(g)
        plot_corr_network(g,con +' '+'co-expression network for candidate species',output_path + con + '-co-expression-network.png',figsize = (15,8))
        #### taxonomy set enrichment analysis
        tsea = taxonomy_enrich_analysis(deseq_output=deseq_df,metaphlan_output=metaphlan,humann_index=None,graph=g,taxonomy=None)
        node_df = tsea.TSEA(mode='Node',sorted=False).sort_values(by='Pathway')
        edge_df = tsea.TSEA(mode='Edge',sorted=False).sort_values(by='Pathway')
        tsea_df = pd.DataFrame({'Name' : node_df['Pathway'],'Node-pseudo-F' : node_df['p-value'],'Edge-pseudo-F' : edge_df['p-value']})
        tsea_df.index = tsea_df['Name'].values
        tsea_df.to_csv(tsea_output + con + '-TSEA-output.txt',sep='\t')

        ###plot sub network
        nx.get_node_attributes(g,'Cluster')
        cluster_list = list(set(nx.get_node_attributes(g,'Cluster').values()))
        cluster_list.remove('No cluster')
        for c in cluster_list :
            g_sub = subgraph(g,attr='Cluster',candidate=c)
            print("Cluster : {c} node pseudo F : {node}, edge pseudo F : {edge}".format(c=c,node = tsea_df.loc[c,'Node-pseudo-F'],edge =tsea_df.loc[c,'Edge-pseudo-F'] ))
            if tsea_df.loc[c,'Node-pseudo-F'] < 0.05 and tsea_df.loc[c,'Edge-pseudo-F'] < 0.05 :

                represent_s,_ = sorted(g_sub.degree, key=lambda x: x[1], reverse=True)[0]
                #stat of subnetwork member
                sub_s = list(g_sub.nodes())
                sub_deseq_df = deseq_df.loc[sub_s,:].copy()
                df_file_name = output_path + con + '-' + 'co-expression-subnetwork' + '-' + represent_s + '.txt'
                sub_deseq_df.to_csv(df_file_name,sep='\t')
                ##plot subnetwork
                subnetwork_title = con + ' ' + 'subnetwork for' + ' ' + c + ' ' + '('+ represent_s + ')'
                file_name = output_path + con + '-' + 'co-expression-subnetwork' + '-' + represent_s + '.png'
                plot_corr_network(g_sub,subnetwork_title,file_name,figsize = (15,8),fontsize=12)
                if con == 'Overall' :
                    scatter_title = 'Subnetwork scatterplot for' + ' ' + c + ' ' + '('+ represent_s + ')'
                    scatter_name = output_path + 'Subnetwork scatterplot for' + ' ' + c + ' ' + '('+ represent_s + ')' + '.png'
                    node_scatter_subplot(g_sub,candidate,diagnosis_idx,scatter_title,scatter_name,'MCI','normal')
            else :
                pass

# %%
main()

# %%
tsea_output = '/home/bruce1996/data/MCI/tsea/'
con = ['Overall','MCI','Normal']
for c in con :
    name = tsea_output + c + '-TSEA-output.txt'
    df = pd.read_csv(name,sep='\t',index_col=0)
    edge_p = df['Edge-pseudo-F'].values
    sns.scatterplot(data = df,x = 'Node-pseudo-F',y='Edge-pseudo-F',hue = 'Name',palette='rainbow')
    plt.title('Taxonomy set enrichment analysis ' + '(' + c + ')')
    plt.legend(bbox_to_anchor=(1.3, 1))
    plt.savefig(output_path + c + '-TSEA-scatterplot.png',bbox_inches='tight',dpi = 300)
    plt.show()

# %% [markdown]
# ### import kgml file

# %%
from Bio.KEGG.KGML import KGML_parser
#https://biopython.org/docs/1.76/api/Bio.KEGG.KGML.KGML_pathway.html

pathway = KGML_parser.read(open(kgml, 'r'))
component_list = np.empty(29,dtype= object)
for idx,c in enumerate(pathway.compounds) :
    component_list[idx] = c.name
# Out:
# 29
# cpd:C02656

# %%
kgml2com_dict = dict()
component_dict = dict()
kgml_path = '/home/bruce1996/data/MCI/kegg/'
kgml_list = os.listdir(kgml_path)

n=0
for f in kgml_list :
    if f[-4:] != 'kgml' :
        pass
    else :
        n += 1
        print('Parse %d st kgml file : %s' % (n,f))
        map_name = 'map' + f[3:]
        filename = kgml_path + f
        ##parse kgml file
        pathway = KGML_parser.read(open(filename, 'r'))
        n_component = len(pathway.compounds)
        component_list = np.empty(n_component,dtype= object)
        for idx,c in enumerate(pathway.compounds) :
            component_list[idx] = c.name
            if c.name not in component_dict.keys() :
                component_dict[c.name] = 0
            else :
                component_dict[c.name] += 1

        if map_name not in kgml2com_dict.keys() :
            kgml2com_dict[map_name] = component_list
# Out:
# Parse 1 st kgml file : lcx00650.kgml
# Parse 2 st kgml file : lpl00780.kgml
# Parse 3 st kgml file : lfe01110.kgml
# Parse 4 st kgml file : lca00380.kgml
# Parse 5 st kgml file : lca00361.kgml
# Parse 6 st kgml file : lfe00680.kgml
# Parse 7 st kgml file : lpl00460.kgml
# Parse 8 st kgml file : lre00630.kgml
# Parse 9 st kgml file : lre00660.kgml
# Parse 10 st kgml file : lpl00030.kgml
# Parse 11 st kgml file : lre00520.kgml
# Parse 12 st kgml file : lpl00521.kgml
# Parse 13 st kgml file : lca00430.kgml
# Parse 14 st kgml file : lca03430.kgml
# Parse 15 st kgml file : lre02024.kgml
# Parse 16 st kgml file : lrh03010.kgml
# Parse 17 st kgml file : lcx00780.kgml
# Parse 18 st kgml file : lac01212.kgml
# Parse 19 st kgml file : lcx00541.kgml
# Parse 20 st kgml file : bcoa00020.kgml
# Parse 21 st kgml file : lcx00770.kgml
# Parse 22 st kgml file : lac01502.kgml
# Parse 23 st kgml file : lre01212.kgml
# Parse 24 st kgml file : lpl03430.kgml
# Parse 25 st kgml file : lca01120.kgml
# Parse 26 st kgml file : lre00350.kgml
# Parse 27 st kgml file : lrh03070.kgml
# Parse 28 st kgml file : lpl01110.kgml
# Parse 29 st kgml file : bcoa01200.kgml
# Parse 30 st kgml file : lca00750.kgml
# Parse 31 st kgml file : bcoa01250.kgml
# Parse 32 st kgml file : lcx00330.kgml
# Parse 33 st kgml file : lfe00970.kgml
# Parse 34 st kgml file : bbb00525.kgml
# Parse 35 st kgml file : lpl00500.kgml
# Parse 36 st kgml file : lca00071.kgml
# Parse 37 st kgml file : lre00900.kgml
# Parse 38 st kgml file : lac00640.kgml
# Parse 39 st kgml file : lrh02060.kgml
# Parse 40 st kgml file : lcx01503.kgml
# Parse 41 st kgml file : bcoa03450.kgml
# Parse 42 st kgml file : lpl03020.kgml
# Parse 43 st kgml file : lfe03070.kgml
# Parse 44 st kgml file : lpl03420.kgml
# Parse 45 st kgml file : lre00680.kgml
# Parse 46 st kgml file : bcoa00561.kgml
# Parse 47 st kgml file : lrh00350.kgml
# Parse 48 st kgml file : bcoa00350.kgml
# Parse 49 st kgml file : bbb01240.kgml
# Parse 50 st kgml file : bcoa00780.kgml
# Parse 51 st kgml file : lfe00780.kgml
# Parse 52 st kgml file : lre00541.kgml
# Parse 53 st kgml file : bbb00640.kgml
# Parse 54 st kgml file : lca03030.kgml
# Parse 55 st kgml file : lpl00362.kgml
# Parse 56 st kgml file : bbb00330.kgml
# Parse 57 st kgml file : lcx01220.kgml
# Parse 58 st kgml file : bbb01110.kgml
# Parse 59 st kgml file : bbb00650.kgml
# Parse 60 st kgml file : lcx01212.kgml
# Parse 61 st kgml file : lcx00430.kgml
# Parse 62 st kgml file : bcoa00360.kgml
# Parse 63 st kgml file : bbb00450.kgml
# Parse 64 st kgml file : lpl00220.kgml
# Parse 65 st kgml file : lpl00552.kgml
# Parse 66 st kgml file : bcoa01110.kgml
# Parse 67 st kgml file : lac00552.kgml
# Parse 68 st kgml file : lfe00061.kgml
# Parse 69 st kgml file : bcoa03070.kgml
# Parse 70 st kgml file : bcoa00640.kgml
# Parse 71 st kgml file : bbb00400.kgml
# Parse 72 st kgml file : lrh00525.kgml
# Parse 73 st kgml file : lcx00730.kgml
# Parse 74 st kgml file : bbb03440.kgml
# Parse 75 st kgml file : lca00640.kgml
# Parse 76 st kgml file : lfe01240.kgml
# Parse 77 st kgml file : lrh00520.kgml
# Parse 78 st kgml file : bbb00999.kgml
# Parse 79 st kgml file : lfe00600.kgml
# Parse 80 st kgml file : lcx02024.kgml
# Parse 81 st kgml file : lfe00470.kgml
# Parse 82 st kgml file : lpl01240.kgml
# Parse 83 st kgml file : bcoa00521.kgml
# Parse 84 st kgml file : lca00511.kgml
# Parse 85 st kgml file : lcx00860.kgml
# Parse 86 st kgml file : lca00270.kgml
# Parse 87 st kgml file : lca01501.kgml
# Parse 88 st kgml file : lre03060.kgml
# Parse 89 st kgml file : lpl00511.kgml
# Parse 90 st kgml file : bbb00660.kgml
# Parse 91 st kgml file : bbb00480.kgml
# Parse 92 st kgml file : lpl01220.kgml
# Parse 93 st kgml file : lfe00362.kgml
# Parse 94 st kgml file : lre00460.kgml
# Parse 95 st kgml file : lrh03020.kgml
# Parse 96 st kgml file : lca00627.kgml
# Parse 97 st kgml file : lre00362.kgml
# Parse 98 st kgml file : lcx00740.kgml
# Parse 99 st kgml file : bcoa00790.kgml
# Parse 100 st kgml file : lcx00130.kgml
# Parse 101 st kgml file : lca00300.kgml
# Parse 102 st kgml file : bcoa00626.kgml
# Parse 103 st kgml file : lca02020.kgml
# Parse 104 st kgml file : lpl00240.kgml
# Parse 105 st kgml file : lpl01232.kgml
# Parse 106 st kgml file : lcx00051.kgml
# Parse 107 st kgml file : lpl00970.kgml
# Parse 108 st kgml file : lcx00240.kgml
# Parse 109 st kgml file : lac00770.kgml
# Parse 110 st kgml file : lre00052.kgml
# Parse 111 st kgml file : lrh00625.kgml
# Parse 112 st kgml file : lca00600.kgml
# Parse 113 st kgml file : lfe00280.kgml
# Parse 114 st kgml file : lcx03070.kgml
# Parse 115 st kgml file : lca00340.kgml
# Parse 116 st kgml file : lre00040.kgml
# Parse 117 st kgml file : lrh00760.kgml
# Parse 118 st kgml file : lre00500.kgml
# Parse 119 st kgml file : lfe00300.kgml
# Parse 120 st kgml file : lrh00051.kgml
# Parse 121 st kgml file : lrh00523.kgml
# Parse 122 st kgml file : lca00332.kgml
# Parse 123 st kgml file : bcoa00051.kgml
# Parse 124 st kgml file : lca00561.kgml
# Parse 125 st kgml file : lpl00670.kgml
# Parse 126 st kgml file : bbb00552.kgml
# Parse 127 st kgml file : lpl01054.kgml
# Parse 128 st kgml file : lrh01200.kgml
# Parse 129 st kgml file : bbb00541.kgml
# Parse 130 st kgml file : lrh01110.kgml
# Parse 131 st kgml file : lpl01501.kgml
# Parse 132 st kgml file : lac00310.kgml
# Parse 133 st kgml file : bcoa04122.kgml
# Parse 134 st kgml file : bbb00500.kgml
# Parse 135 st kgml file : lrh00643.kgml
# Parse 136 st kgml file : lrh00541.kgml
# Parse 137 st kgml file : lcx02060.kgml
# Parse 138 st kgml file : lca00523.kgml
# Parse 139 st kgml file : lcx00785.kgml
# Parse 140 st kgml file : lre03440.kgml
# Parse 141 st kgml file : lfe00643.kgml
# Parse 142 st kgml file : lcx04122.kgml
# Parse 143 st kgml file : lpl00061.kgml
# Parse 144 st kgml file : lre00920.kgml
# Parse 145 st kgml file : lca00785.kgml
# Parse 146 st kgml file : bcoa00220.kgml
# Parse 147 st kgml file : bcoa00190.kgml
# Parse 148 st kgml file : lre01503.kgml
# Parse 149 st kgml file : lac00620.kgml
# Parse 150 st kgml file : lfe03010.kgml
# Parse 151 st kgml file : lca00460.kgml
# Parse 152 st kgml file : lcx01501.kgml
# Parse 153 st kgml file : lcx00500.kgml
# Parse 154 st kgml file : lpl00250.kgml
# Parse 155 st kgml file : lfe00770.kgml
# Parse 156 st kgml file : bcoa00281.kgml
# Parse 157 st kgml file : bcoa00332.kgml
# Parse 158 st kgml file : bcoa00030.kgml
# Parse 159 st kgml file : bbb00521.kgml
# Parse 160 st kgml file : lre00470.kgml
# Parse 161 st kgml file : bcoa00670.kgml
# Parse 162 st kgml file : lca00680.kgml
# Parse 163 st kgml file : lca00220.kgml
# Parse 164 st kgml file : lfe00622.kgml
# Parse 165 st kgml file : lrh00562.kgml
# Parse 166 st kgml file : bbb00562.kgml
# Parse 167 st kgml file : lfe03410.kgml
# Parse 168 st kgml file : bbb03410.kgml
# Parse 169 st kgml file : lrh00020.kgml
# Parse 170 st kgml file : bbb00261.kgml
# Parse 171 st kgml file : bcoa02040.kgml
# Parse 172 st kgml file : bcoa00625.kgml
# Parse 173 st kgml file : lcx03420.kgml
# Parse 174 st kgml file : bbb03420.kgml
# Parse 175 st kgml file : lre00562.kgml
# Parse 176 st kgml file : lrh01100.kgml
# Parse 177 st kgml file : lpl02040.kgml
# Parse 178 st kgml file : bbb00061.kgml
# Parse 179 st kgml file : lre03420.kgml
# Parse 180 st kgml file : lpl00523.kgml
# Parse 181 st kgml file : lrh01210.kgml
# Parse 182 st kgml file : bcoa00040.kgml
# Parse 183 st kgml file : lcx00332.kgml
# Parse 184 st kgml file : lrh01503.kgml
# Parse 185 st kgml file : lpl00760.kgml
# Parse 186 st kgml file : lpl00480.kgml
# Parse 187 st kgml file : lrh01212.kgml
# Parse 188 st kgml file : lcx00230.kgml
# Parse 189 st kgml file : lcx00260.kgml
# Parse 190 st kgml file : lre00380.kgml
# Parse 191 st kgml file : lrh00630.kgml
# Parse 192 st kgml file : bbb00340.kgml
# Parse 193 st kgml file : bbb00270.kgml
# Parse 194 st kgml file : lfe00360.kgml
# Parse 195 st kgml file : lrh02040.kgml
# Parse 196 st kgml file : lrh00240.kgml
# Parse 197 st kgml file : lcx00061.kgml
# Parse 198 st kgml file : lca01250.kgml
# Parse 199 st kgml file : lrh02010.kgml
# Parse 200 st kgml file : bbb01100.kgml
# Parse 201 st kgml file : lre00480.kgml
# Parse 202 st kgml file : lrh00970.kgml
# Parse 203 st kgml file : lca00541.kgml
# Parse 204 st kgml file : lca00564.kgml
# Parse 205 st kgml file : lpl00525.kgml
# Parse 206 st kgml file : lrh00550.kgml
# Parse 207 st kgml file : bbb00770.kgml
# Parse 208 st kgml file : lcx00625.kgml
# Parse 209 st kgml file : lac00626.kgml
# Parse 210 st kgml file : lpl01503.kgml
# Parse 211 st kgml file : lpl01250.kgml
# Parse 212 st kgml file : lre00450.kgml
# Parse 213 st kgml file : bcoa00590.kgml
# Parse 214 st kgml file : lre00650.kgml
# Parse 215 st kgml file : lca00052.kgml
# Parse 216 st kgml file : lcx00590.kgml
# Parse 217 st kgml file : lrh00900.kgml
# Parse 218 st kgml file : lre00564.kgml
# Parse 219 st kgml file : lrh00999.kgml
# Parse 220 st kgml file : bcoa01503.kgml
# Parse 221 st kgml file : lre02040.kgml
# Parse 222 st kgml file : lrh00300.kgml
# Parse 223 st kgml file : lcx03020.kgml
# Parse 224 st kgml file : bcoa00740.kgml
# Parse 225 st kgml file : lpl04122.kgml
# Parse 226 st kgml file : bcoa01230.kgml
# Parse 227 st kgml file : lrh03420.kgml
# Parse 228 st kgml file : lfe00627.kgml
# Parse 229 st kgml file : lpl03030.kgml
# Parse 230 st kgml file : lpl00860.kgml
# Parse 231 st kgml file : bcoa02010.kgml
# Parse 232 st kgml file : lca00970.kgml
# Parse 233 st kgml file : lrh00790.kgml
# Parse 234 st kgml file : lac00121.kgml
# Parse 235 st kgml file : lpl02060.kgml
# Parse 236 st kgml file : lac00300.kgml
# Parse 237 st kgml file : bbb01232.kgml
# Parse 238 st kgml file : bbb00542.kgml
# Parse 239 st kgml file : lfe00785.kgml
# Parse 240 st kgml file : lrh00770.kgml
# Parse 241 st kgml file : lcx02010.kgml
# Parse 242 st kgml file : lfe01100.kgml
# Parse 243 st kgml file : bbb01200.kgml
# Parse 244 st kgml file : bcoa00010.kgml
# Parse 245 st kgml file : lpl00051.kgml
# Parse 246 st kgml file : lac00430.kgml
# Parse 247 st kgml file : lcx00480.kgml
# Parse 248 st kgml file : lac00625.kgml
# Parse 249 st kgml file : lac03018.kgml
# Parse 250 st kgml file : lfe01120.kgml
# Parse 251 st kgml file : lfe00220.kgml
# Parse 252 st kgml file : bbb00970.kgml
# Parse 253 st kgml file : bcoa01220.kgml
# Parse 254 st kgml file : lfe00430.kgml
# Parse 255 st kgml file : lre00260.kgml
# Parse 256 st kgml file : lrh00010.kgml
# Parse 257 st kgml file : lac02020.kgml
# Parse 258 st kgml file : lrh00430.kgml
# Parse 259 st kgml file : lac00670.kgml
# Parse 260 st kgml file : lac00240.kgml
# Parse 261 st kgml file : lfe00051.kgml
# Parse 262 st kgml file : lrh03018.kgml
# Parse 263 st kgml file : lre00250.kgml
# Parse 264 st kgml file : lfe00564.kgml
# Parse 265 st kgml file : lre00785.kgml
# Parse 266 st kgml file : bbb00121.kgml
# Parse 267 st kgml file : lca00760.kgml
# Parse 268 st kgml file : bbb00332.kgml
# Parse 269 st kgml file : lre01232.kgml
# Parse 270 st kgml file : lrh00521.kgml
# Parse 271 st kgml file : lpl00410.kgml
# Parse 272 st kgml file : lcx00290.kgml
# Parse 273 st kgml file : lpl00290.kgml
# Parse 274 st kgml file : lre00511.kgml
# Parse 275 st kgml file : lcx00552.kgml
# Parse 276 st kgml file : lpl01230.kgml
# Parse 277 st kgml file : lac03430.kgml
# Parse 278 st kgml file : lpl00380.kgml
# Parse 279 st kgml file : lfe00450.kgml
# Parse 280 st kgml file : lrh00280.kgml
# Parse 281 st kgml file : bbb01501.kgml
# Parse 282 st kgml file : lfe03030.kgml
# Parse 283 st kgml file : lre00970.kgml
# Parse 284 st kgml file : lca00740.kgml
# Parse 285 st kgml file : lrh03030.kgml
# Parse 286 st kgml file : lca03060.kgml
# Parse 287 st kgml file : lpl00350.kgml
# Parse 288 st kgml file : lpl02010.kgml
# Parse 289 st kgml file : lre00521.kgml
# Parse 290 st kgml file : bcoa00270.kgml
# Parse 291 st kgml file : bbb02024.kgml
# Parse 292 st kgml file : bcoa00660.kgml
# Parse 293 st kgml file : bcoa00520.kgml
# Parse 294 st kgml file : bcoa00401.kgml
# Parse 295 st kgml file : bcoa00860.kgml
# Parse 296 st kgml file : lcx00627.kgml
# Parse 297 st kgml file : lca04122.kgml
# Parse 298 st kgml file : lrh00310.kgml
# Parse 299 st kgml file : bcoa00785.kgml
# Parse 300 st kgml file : lre00290.kgml
# Parse 301 st kgml file : lca00562.kgml
# Parse 302 st kgml file : lpl00520.kgml
# Parse 303 st kgml file : bbb00910.kgml
# Parse 304 st kgml file : lpl00660.kgml
# Parse 305 st kgml file : lca00360.kgml
# Parse 306 st kgml file : lcx03018.kgml
# Parse 307 st kgml file : lcx00520.kgml
# Parse 308 st kgml file : lca00920.kgml
# Parse 309 st kgml file : lre00790.kgml
# Parse 310 st kgml file : lca02024.kgml
# Parse 311 st kgml file : bcoa01120.kgml
# Parse 312 st kgml file : lac03410.kgml
# Parse 313 st kgml file : lac03070.kgml
# Parse 314 st kgml file : bbb00053.kgml
# Parse 315 st kgml file : bbb03070.kgml
# Parse 316 st kgml file : bcoa00261.kgml
# Parse 317 st kgml file : bcoa00630.kgml
# Parse 318 st kgml file : lfe00520.kgml
# Parse 319 st kgml file : lfe00525.kgml
# Parse 320 st kgml file : lac00860.kgml
# Parse 321 st kgml file : lca00622.kgml
# Parse 322 st kgml file : lca00240.kgml
# Parse 323 st kgml file : bbb00051.kgml
# Parse 324 st kgml file : lrh00920.kgml
# Parse 325 st kgml file : lrh01054.kgml
# Parse 326 st kgml file : lpl00627.kgml
# Parse 327 st kgml file : lfe00190.kgml
# Parse 328 st kgml file : lac00541.kgml
# Parse 329 st kgml file : lrh00561.kgml
# Parse 330 st kgml file : bbb00523.kgml
# Parse 331 st kgml file : lfe00310.kgml
# Parse 332 st kgml file : lcx03410.kgml
# Parse 333 st kgml file : lpl00270.kgml
# Parse 334 st kgml file : lpl00280.kgml
# Parse 335 st kgml file : lcx00620.kgml
# Parse 336 st kgml file : bbb00600.kgml
# Parse 337 st kgml file : lfe03060.kgml
# Parse 338 st kgml file : lrh00040.kgml
# Parse 339 st kgml file : lca01210.kgml
# Parse 340 st kgml file : lac01120.kgml
# Parse 341 st kgml file : lcx03030.kgml
# Parse 342 st kgml file : lfe01200.kgml
# Parse 343 st kgml file : lre00051.kgml
# Parse 344 st kgml file : lfe01054.kgml
# Parse 345 st kgml file : bcoa03420.kgml
# Parse 346 st kgml file : bbb00010.kgml
# Parse 347 st kgml file : lca00030.kgml
# Parse 348 st kgml file : lre00910.kgml
# Parse 349 st kgml file : bbb00071.kgml
# Parse 350 st kgml file : lcx01232.kgml
# Parse 351 st kgml file : lfe00130.kgml
# Parse 352 st kgml file : bcoa02030.kgml
# Parse 353 st kgml file : bbb00460.kgml
# Parse 354 st kgml file : lfe03440.kgml
# Parse 355 st kgml file : lre04122.kgml
# Parse 356 st kgml file : bcoa00460.kgml
# Parse 357 st kgml file : lrh00626.kgml
# Parse 358 st kgml file : lfe00260.kgml
# Parse 359 st kgml file : lcx01100.kgml
# Parse 360 st kgml file : lcx00564.kgml
# Parse 361 st kgml file : lrh00053.kgml
# Parse 362 st kgml file : lpl00020.kgml
# Parse 363 st kgml file : bbb01210.kgml
# Parse 364 st kgml file : lcx00270.kgml
# Parse 365 st kgml file : lre00130.kgml
# Parse 366 st kgml file : lfe00621.kgml
# Parse 367 st kgml file : lre00552.kgml
# Parse 368 st kgml file : lfe00740.kgml
# Parse 369 st kgml file : lac00480.kgml
# Parse 370 st kgml file : lre01120.kgml
# Parse 371 st kgml file : lca03410.kgml
# Parse 372 st kgml file : bcoa01232.kgml
# Parse 373 st kgml file : bbb00785.kgml
# Parse 374 st kgml file : bcoa03410.kgml
# Parse 375 st kgml file : lre01054.kgml
# Parse 376 st kgml file : lca00230.kgml
# Parse 377 st kgml file : lac00730.kgml
# Parse 378 st kgml file : lca00290.kgml
# Parse 379 st kgml file : lca00310.kgml
# Parse 380 st kgml file : lpl00261.kgml
# Parse 381 st kgml file : lrh00061.kgml
# Parse 382 st kgml file : bcoa00300.kgml
# Parse 383 st kgml file : bcoa00062.kgml
# Parse 384 st kgml file : lrh00071.kgml
# Parse 385 st kgml file : lre00640.kgml
# Parse 386 st kgml file : lac02060.kgml
# Parse 387 st kgml file : lpl00310.kgml
# Parse 388 st kgml file : bbb00750.kgml
# Parse 389 st kgml file : lac00900.kgml
# Parse 390 st kgml file : lcx00380.kgml
# Parse 391 st kgml file : lfe00562.kgml
# Parse 392 st kgml file : lrh00640.kgml
# Parse 393 st kgml file : bbb00680.kgml
# Parse 394 st kgml file : lcx00790.kgml
# Parse 395 st kgml file : lpl00400.kgml
# Parse 396 st kgml file : lac00061.kgml
# Parse 397 st kgml file : bcoa03010.kgml
# Parse 398 st kgml file : lre02010.kgml
# Parse 399 st kgml file : lca03440.kgml
# Parse 400 st kgml file : lre00330.kgml
# Parse 401 st kgml file : lfe00670.kgml
# Parse 402 st kgml file : lpl00541.kgml
# Parse 403 st kgml file : lrh00361.kgml
# Parse 404 st kgml file : lac01110.kgml
# Parse 405 st kgml file : lca03018.kgml
# Parse 406 st kgml file : lcx00680.kgml
# Parse 407 st kgml file : lfe01250.kgml
# Parse 408 st kgml file : bcoa00627.kgml
# Parse 409 st kgml file : bcoa00260.kgml
# Parse 410 st kgml file : lre00626.kgml
# Parse 411 st kgml file : lca00521.kgml
# Parse 412 st kgml file : bcoa00380.kgml
# Parse 413 st kgml file : lac02024.kgml
# Parse 414 st kgml file : lpl00401.kgml
# Parse 415 st kgml file : bcoa01501.kgml
# Parse 416 st kgml file : lcx02020.kgml
# Parse 417 st kgml file : lfe01220.kgml
# Parse 418 st kgml file : lrh00380.kgml
# Parse 419 st kgml file : lrh00740.kgml
# Parse 420 st kgml file : lca02010.kgml
# Parse 421 st kgml file : lrh00552.kgml
# Parse 422 st kgml file : lcx00511.kgml
# Parse 423 st kgml file : bcoa00760.kgml
# Parse 424 st kgml file : bcoa00290.kgml
# Parse 425 st kgml file : bbb00561.kgml
# Parse 426 st kgml file : lca00470.kgml
# Parse 427 st kgml file : lrh00261.kgml
# Parse 428 st kgml file : lac00190.kgml
# Parse 429 st kgml file : bcoa00550.kgml
# Parse 430 st kgml file : lrh00680.kgml
# Parse 431 st kgml file : lcx00310.kgml
# Parse 432 st kgml file : lpl00040.kgml
# Parse 433 st kgml file : bbb00360.kgml
# Parse 434 st kgml file : lac00260.kgml
# Parse 435 st kgml file : lfe01210.kgml
# Parse 436 st kgml file : lpl00053.kgml
# Parse 437 st kgml file : lrh03060.kgml
# Parse 438 st kgml file : lac01100.kgml
# Parse 439 st kgml file : bcoa03020.kgml
# Parse 440 st kgml file : lrh01501.kgml
# Parse 441 st kgml file : lcx00622.kgml
# Parse 442 st kgml file : lcx00010.kgml
# Parse 443 st kgml file : lac00051.kgml
# Parse 444 st kgml file : lpl00332.kgml
# Parse 445 st kgml file : lcx00910.kgml
# Parse 446 st kgml file : bcoa03060.kgml
# Parse 447 st kgml file : lcx03010.kgml
# Parse 448 st kgml file : lac00920.kgml
# Parse 449 st kgml file : lca00660.kgml
# Parse 450 st kgml file : lfe00250.kgml
# Parse 451 st kgml file : lac00130.kgml
# Parse 452 st kgml file : bcoa00130.kgml
# Parse 453 st kgml file : lfe01503.kgml
# Parse 454 st kgml file : lcx00350.kgml
# Parse 455 st kgml file : lca03420.kgml
# Parse 456 st kgml file : bbb01120.kgml
# Parse 457 st kgml file : bcoa00250.kgml
# Parse 458 st kgml file : lcx01230.kgml
# Parse 459 st kgml file : bcoa00280.kgml
# Parse 460 st kgml file : lca01502.kgml
# Parse 461 st kgml file : bcoa00052.kgml
# Parse 462 st kgml file : bcoa00500.kgml
# Parse 463 st kgml file : lcx00970.kgml
# Parse 464 st kgml file : lpl02020.kgml
# Parse 465 st kgml file : lrh00590.kgml
# Parse 466 st kgml file : lre01240.kgml
# Parse 467 st kgml file : lac00071.kgml
# Parse 468 st kgml file : bcoa00540.kgml
# Parse 469 st kgml file : lac00511.kgml
# Parse 470 st kgml file : lcx01110.kgml
# Parse 471 st kgml file : lpl00311.kgml
# Parse 472 st kgml file : lpl00906.kgml
# Parse 473 st kgml file : bcoa03430.kgml
# Parse 474 st kgml file : lre00780.kgml
# Parse 475 st kgml file : bbb00740.kgml
# Parse 476 st kgml file : lac00780.kgml
# Parse 477 st kgml file : lre00121.kgml
# Parse 478 st kgml file : lpl00130.kgml
# Parse 479 st kgml file : lfe00550.kgml
# Parse 480 st kgml file : lrh00903.kgml
# Parse 481 st kgml file : bcoa00230.kgml
# Parse 482 st kgml file : lrh00650.kgml
# Parse 483 st kgml file : lcx00521.kgml
# Parse 484 st kgml file : bcoa02024.kgml
# Parse 485 st kgml file : lfe00401.kgml
# Parse 486 st kgml file : lrh01502.kgml
# Parse 487 st kgml file : lre00620.kgml
# Parse 488 st kgml file : lcx02040.kgml
# Parse 489 st kgml file : lrh00460.kgml
# Parse 490 st kgml file : lcx00361.kgml
# Parse 491 st kgml file : lfe00500.kgml
# Parse 492 st kgml file : lca00362.kgml
# Parse 493 st kgml file : lpl00450.kgml
# Parse 494 st kgml file : bbb00030.kgml
# Parse 495 st kgml file : lrh00860.kgml
# Parse 496 st kgml file : lre00010.kgml
# Parse 497 st kgml file : lre00310.kgml
# Parse 498 st kgml file : lpl00740.kgml
# Parse 499 st kgml file : bbb03250.kgml
# Parse 500 st kgml file : bcoa00400.kgml
# Parse 501 st kgml file : lcx01120.kgml
# Parse 502 st kgml file : bbb00626.kgml
# Parse 503 st kgml file : lfe00330.kgml
# Parse 504 st kgml file : lac00270.kgml
# Parse 505 st kgml file : bbb00290.kgml
# Parse 506 st kgml file : bcoa00541.kgml
# Parse 507 st kgml file : lpl00190.kgml
# Parse 508 st kgml file : bcoa00680.kgml
# Parse 509 st kgml file : bbb00670.kgml
# Parse 510 st kgml file : lrh00230.kgml
# Parse 511 st kgml file : lca00590.kgml
# Parse 512 st kgml file : lcx00630.kgml
# Parse 513 st kgml file : lfe00625.kgml
# Parse 514 st kgml file : lpl00730.kgml
# Parse 515 st kgml file : lca00520.kgml
# Parse 516 st kgml file : bcoa00910.kgml
# Parse 517 st kgml file : lrh00030.kgml
# Parse 518 st kgml file : lre03430.kgml
# Parse 519 st kgml file : bcoa00450.kgml
# Parse 520 st kgml file : lca00130.kgml
# Parse 521 st kgml file : lcx00220.kgml
# Parse 522 st kgml file : lre00625.kgml
# Parse 523 st kgml file : lrh00330.kgml
# Parse 524 st kgml file : lca00400.kgml
# Parse 525 st kgml file : lre00523.kgml
# Parse 526 st kgml file : lcx00040.kgml
# Parse 527 st kgml file : bbb00260.kgml
# Parse 528 st kgml file : lre00190.kgml
# Parse 529 st kgml file : bcoa00920.kgml
# Parse 530 st kgml file : lfe02020.kgml
# Parse 531 st kgml file : lfe00640.kgml
# Parse 532 st kgml file : lfe00523.kgml
# Parse 533 st kgml file : bcoa00430.kgml
# Parse 534 st kgml file : lcx01200.kgml
# Parse 535 st kgml file : lca00190.kgml
# Parse 536 st kgml file : lac03060.kgml
# Parse 537 st kgml file : bcoa00410.kgml
# Parse 538 st kgml file : lfe01232.kgml
# Parse 539 st kgml file : lre00270.kgml
# Parse 540 st kgml file : bcoa00480.kgml
# Parse 541 st kgml file : lfe03420.kgml
# Parse 542 st kgml file : bcoa02020.kgml
# Parse 543 st kgml file : lcx00750.kgml
# Parse 544 st kgml file : bcoa00650.kgml
# Parse 545 st kgml file : lac00230.kgml
# Parse 546 st kgml file : lrh00627.kgml
# Parse 547 st kgml file : lcx00600.kgml
# Parse 548 st kgml file : lcx00760.kgml
# Parse 549 st kgml file : lpl03440.kgml
# Parse 550 st kgml file : lca03020.kgml
# Parse 551 st kgml file : lca00040.kgml
# Parse 552 st kgml file : lfe01212.kgml
# Parse 553 st kgml file : lpl01212.kgml
# Parse 554 st kgml file : lrh00730.kgml
# Parse 555 st kgml file : lac00550.kgml
# Parse 556 st kgml file : bcoa00310.kgml
# Parse 557 st kgml file : bbb00190.kgml
# Parse 558 st kgml file : lpl00650.kgml
# Parse 559 st kgml file : lfe00400.kgml
# Parse 560 st kgml file : lfe00480.kgml
# Parse 561 st kgml file : bbb00052.kgml
# Parse 562 st kgml file : lpl01100.kgml
# Parse 563 st kgml file : lcx01054.kgml
# Parse 564 st kgml file : bcoa00620.kgml
# Parse 565 st kgml file : lfe00920.kgml
# Parse 566 st kgml file : lpl00770.kgml
# Parse 567 st kgml file : bbb00040.kgml
# Parse 568 st kgml file : lre00643.kgml
# Parse 569 st kgml file : lre00430.kgml
# Parse 570 st kgml file : lpl00900.kgml
# Parse 571 st kgml file : lrh02024.kgml
# Parse 572 st kgml file : lca01240.kgml
# Parse 573 st kgml file : lre03010.kgml
# Parse 574 st kgml file : lre00071.kgml
# Parse 575 st kgml file : lca00900.kgml
# Parse 576 st kgml file : lpl00910.kgml
# Parse 577 st kgml file : lre01250.kgml
# Parse 578 st kgml file : lac00470.kgml
# Parse 579 st kgml file : lca00525.kgml
# Parse 580 st kgml file : lca00350.kgml
# Parse 581 st kgml file : bcoa00750.kgml
# Parse 582 st kgml file : lrh00052.kgml
# Parse 583 st kgml file : bcoa00362.kgml
# Parse 584 st kgml file : lac00250.kgml
# Parse 585 st kgml file : lac00280.kgml
# Parse 586 st kgml file : bbb00511.kgml
# Parse 587 st kgml file : bbb00760.kgml
# Parse 588 st kgml file : lre00061.kgml
# Parse 589 st kgml file : lfe00620.kgml
# Parse 590 st kgml file : lfe04122.kgml
# Parse 591 st kgml file : lcx01502.kgml
# Parse 592 st kgml file : bbb00900.kgml
# Parse 593 st kgml file : lre00622.kgml
# Parse 594 st kgml file : lca01110.kgml
# Parse 595 st kgml file : lac01210.kgml
# Parse 596 st kgml file : lre01501.kgml
# Parse 597 st kgml file : lac03030.kgml
# Parse 598 st kgml file : bbb00625.kgml
# Parse 599 st kgml file : lpl00622.kgml
# Parse 600 st kgml file : lpl00550.kgml
# Parse 601 st kgml file : lca00625.kgml
# Parse 602 st kgml file : lrh00785.kgml
# Parse 603 st kgml file : lfe03020.kgml
# Parse 604 st kgml file : bcoa00470.kgml
# Parse 605 st kgml file : lac00561.kgml
# Parse 606 st kgml file : lre01110.kgml
# Parse 607 st kgml file : lpl00640.kgml
# Parse 608 st kgml file : lcx00280.kgml
# Parse 609 st kgml file : lca00620.kgml
# Parse 610 st kgml file : lfe00460.kgml
# Parse 611 st kgml file : bbb01220.kgml
# Parse 612 st kgml file : lre00627.kgml
# Parse 613 st kgml file : lcx00053.kgml
# Parse 614 st kgml file : lpl01200.kgml
# Parse 615 st kgml file : lrh00780.kgml
# Parse 616 st kgml file : lac00564.kgml
# Parse 617 st kgml file : lfe00010.kgml
# Parse 618 st kgml file : lrh00332.kgml
# Parse 619 st kgml file : lcx00643.kgml
# Parse 620 st kgml file : bbb02010.kgml
# Parse 621 st kgml file : lre01230.kgml
# Parse 622 st kgml file : lca00053.kgml
# Parse 623 st kgml file : lrh00500.kgml
# Parse 624 st kgml file : lac00500.kgml
# Parse 625 st kgml file : lfe01230.kgml
# Parse 626 st kgml file : lcx00450.kgml
# Parse 627 st kgml file : lca01212.kgml
# Parse 628 st kgml file : lpl00680.kgml
# Parse 629 st kgml file : bcoa00340.kgml
# Parse 630 st kgml file : lpl03010.kgml
# Parse 631 st kgml file : lca00051.kgml
# Parse 632 st kgml file : bbb00280.kgml
# Parse 633 st kgml file : lcx00626.kgml
# Parse 634 st kgml file : lac01200.kgml
# Parse 635 st kgml file : lcx00562.kgml
# Parse 636 st kgml file : lfe00290.kgml
# Parse 637 st kgml file : lca02060.kgml
# Parse 638 st kgml file : lpl00230.kgml
# Parse 639 st kgml file : lcx00030.kgml
# Parse 640 st kgml file : lrh00190.kgml
# Parse 641 st kgml file : lcx00052.kgml
# Parse 642 st kgml file : bbb03018.kgml
# Parse 643 st kgml file : lfe00040.kgml
# Parse 644 st kgml file : bbb00250.kgml
# Parse 645 st kgml file : bcoa02060.kgml
# Parse 646 st kgml file : bbb00920.kgml
# Parse 647 st kgml file : lre03070.kgml
# Parse 648 st kgml file : bbb01212.kgml
# Parse 649 st kgml file : lca00770.kgml
# Parse 650 st kgml file : lac00600.kgml
# Parse 651 st kgml file : lac04122.kgml
# Parse 652 st kgml file : bcoa00061.kgml
# Parse 653 st kgml file : lac03440.kgml
# Parse 654 st kgml file : lac00542.kgml
# Parse 655 st kgml file : lpl00430.kgml
# Parse 656 st kgml file : lca01220.kgml
# Parse 657 st kgml file : lre00550.kgml
# Parse 658 st kgml file : lrh01240.kgml
# Parse 659 st kgml file : bbb03010.kgml
# Parse 660 st kgml file : lre01502.kgml
# Parse 661 st kgml file : lac00750.kgml
# Parse 662 st kgml file : lpl00360.kgml
# Parse 663 st kgml file : bcoa03030.kgml
# Parse 664 st kgml file : lfe00030.kgml
# Parse 665 st kgml file : lca00261.kgml
# Parse 666 st kgml file : lca03010.kgml
# Parse 667 st kgml file : bcoa01502.kgml
# Parse 668 st kgml file : lac00040.kgml
# Parse 669 st kgml file : bcoa00330.kgml
# Parse 670 st kgml file : lre00410.kgml
# Parse 671 st kgml file : bbb00230.kgml
# Parse 672 st kgml file : lrh01232.kgml
# Parse 673 st kgml file : bbb00550.kgml
# Parse 674 st kgml file : lca02040.kgml
# Parse 675 st kgml file : lre00332.kgml
# Parse 676 st kgml file : lcx00561.kgml
# Parse 677 st kgml file : lcx00071.kgml
# Parse 678 st kgml file : lca00450.kgml
# Parse 679 st kgml file : lpl00999.kgml
# Parse 680 st kgml file : lrh00470.kgml
# Parse 681 st kgml file : lcx00250.kgml
# Parse 682 st kgml file : lac00562.kgml
# Parse 683 st kgml file : lre00240.kgml
# Parse 684 st kgml file : lre00561.kgml
# Parse 685 st kgml file : lca01230.kgml
# Parse 686 st kgml file : bbb00620.kgml
# Parse 687 st kgml file : lca00790.kgml
# Parse 688 st kgml file : lca00280.kgml
# Parse 689 st kgml file : bbb00564.kgml
# Parse 690 st kgml file : lca03070.kgml
# Parse 691 st kgml file : lpl03410.kgml
# Parse 692 st kgml file : lac00680.kgml
# Parse 693 st kgml file : lfe00561.kgml
# Parse 694 st kgml file : bcoa00643.kgml
# Parse 695 st kgml file : bbb03020.kgml
# Parse 696 st kgml file : lrh00130.kgml
# Parse 697 st kgml file : lrh00360.kgml
# Parse 698 st kgml file : lpl00785.kgml
# Parse 699 st kgml file : lac02010.kgml
# Parse 700 st kgml file : lca00061.kgml
# Parse 701 st kgml file : lcx01240.kgml
# Parse 702 st kgml file : lac00290.kgml
# Parse 703 st kgml file : lrh00750.kgml
# Parse 704 st kgml file : lrh00511.kgml
# Parse 705 st kgml file : lcx00360.kgml
# Parse 706 st kgml file : lrh03440.kgml
# Parse 707 st kgml file : lac01240.kgml
# Parse 708 st kgml file : lca00630.kgml
# Parse 709 st kgml file : lre01210.kgml
# Parse 710 st kgml file : lca00250.kgml
# Parse 711 st kgml file : lac00020.kgml
# Parse 712 st kgml file : bbb00514.kgml
# Parse 713 st kgml file : lrh00220.kgml
# Parse 714 st kgml file : lcx00300.kgml
# Parse 715 st kgml file : lac01232.kgml
# Parse 716 st kgml file : lca00020.kgml
# Parse 717 st kgml file : lfe00750.kgml
# Parse 718 st kgml file : lfe00071.kgml
# Parse 719 st kgml file : lpl00340.kgml
# Parse 720 st kgml file : lrh00670.kgml
# Parse 721 st kgml file : bbb00300.kgml
# Parse 722 st kgml file : lfe00650.kgml
# Parse 723 st kgml file : lfe00630.kgml
# Parse 724 st kgml file : lac00650.kgml
# Parse 725 st kgml file : bcoa00592.kgml
# Parse 726 st kgml file : lfe00340.kgml
# Parse 727 st kgml file : lre00770.kgml
# Parse 728 st kgml file : lpl00920.kgml
# Parse 729 st kgml file : bbb00730.kgml
# Parse 730 st kgml file : lac01054.kgml
# Parse 731 st kgml file : lac00630.kgml
# Parse 732 st kgml file : lcx01250.kgml
# Parse 733 st kgml file : lpl03018.kgml
# Parse 734 st kgml file : lcx00660.kgml
# Parse 735 st kgml file : lpl00625.kgml
# Parse 736 st kgml file : lpl01502.kgml
# Parse 737 st kgml file : lrh00362.kgml
# Parse 738 st kgml file : bbb00520.kgml
# Parse 739 st kgml file : lrh00400.kgml
# Parse 740 st kgml file : bcoa03018.kgml
# Parse 741 st kgml file : lre01220.kgml
# Parse 742 st kgml file : bcoa00900.kgml
# Parse 743 st kgml file : lre03018.kgml
# Parse 744 st kgml file : lfe03430.kgml
# Parse 745 st kgml file : bbb01230.kgml
# Parse 746 st kgml file : lcx03440.kgml
# Parse 747 st kgml file : lpl00600.kgml
# Parse 748 st kgml file : lac00740.kgml
# Parse 749 st kgml file : lac00520.kgml
# Parse 750 st kgml file : bbb03030.kgml
# Parse 751 st kgml file : bcoa00542.kgml
# Parse 752 st kgml file : bbb00020.kgml
# Parse 753 st kgml file : lrh01120.kgml
# Parse 754 st kgml file : lfe00020.kgml
# Parse 755 st kgml file : lcx00340.kgml
# Parse 756 st kgml file : lrh00620.kgml
# Parse 757 st kgml file : lac01503.kgml
# Parse 758 st kgml file : lrh00290.kgml
# Parse 759 st kgml file : lfe02040.kgml
# Parse 760 st kgml file : lpl01210.kgml
# Parse 761 st kgml file : lrh03410.kgml
# Parse 762 st kgml file : lrh00450.kgml
# Parse 763 st kgml file : lpl00121.kgml
# Parse 764 st kgml file : lcx00640.kgml
# Parse 765 st kgml file : lrh03430.kgml
# Parse 766 st kgml file : bbb00780.kgml
# Parse 767 st kgml file : lfe01501.kgml
# Parse 768 st kgml file : lcx01210.kgml
# Parse 769 st kgml file : lac03420.kgml
# Parse 770 st kgml file : lpl00470.kgml
# Parse 771 st kgml file : bbb00430.kgml
# Parse 772 st kgml file : bcoa00564.kgml
# Parse 773 st kgml file : lca00330.kgml
# Parse 774 st kgml file : lre03030.kgml
# Parse 775 st kgml file : lfe00240.kgml
# Parse 776 st kgml file : lac01250.kgml
# Parse 777 st kgml file : bbb00350.kgml
# Parse 778 st kgml file : bcoa01240.kgml
# Parse 779 st kgml file : lcx00900.kgml
# Parse 780 st kgml file : lcx00460.kgml
# Parse 781 st kgml file : lrh00480.kgml
# Parse 782 st kgml file : lfe00910.kgml
# Parse 783 st kgml file : lre00261.kgml
# Parse 784 st kgml file : lfe00270.kgml
# Parse 785 st kgml file : lpl00562.kgml
# Parse 786 st kgml file : bcoa00770.kgml
# Parse 787 st kgml file : lfe00730.kgml
# Parse 788 st kgml file : lfe01502.kgml
# Parse 789 st kgml file : lca01503.kgml
# Parse 790 st kgml file : lrh01230.kgml
# Parse 791 st kgml file : lcx00550.kgml
# Parse 792 st kgml file : bcoa01100.kgml
# Parse 793 st kgml file : lfe00860.kgml
# Parse 794 st kgml file : lac00052.kgml
# Parse 795 st kgml file : lfe00511.kgml
# Parse 796 st kgml file : lre00730.kgml
# Parse 797 st kgml file : lac00362.kgml
# Parse 798 st kgml file : lrh02020.kgml
# Parse 799 st kgml file : bcoa01212.kgml
# Parse 800 st kgml file : lrh00910.kgml
# Parse 801 st kgml file : bbb00401.kgml
# Parse 802 st kgml file : lpl00620.kgml
# Parse 803 st kgml file : lcx00261.kgml
# Parse 804 st kgml file : lre00740.kgml
# Parse 805 st kgml file : lpl02024.kgml
# Parse 806 st kgml file : lca00010.kgml
# Parse 807 st kgml file : bbb03060.kgml
# Parse 808 st kgml file : bbb03430.kgml
# Parse 809 st kgml file : lca00999.kgml
# Parse 810 st kgml file : lfe00660.kgml
# Parse 811 st kgml file : lac00760.kgml
# Parse 812 st kgml file : lcx03430.kgml
# Parse 813 st kgml file : lca01054.kgml
# Parse 814 st kgml file : lfe03018.kgml
# Parse 815 st kgml file : lca00260.kgml
# Parse 816 st kgml file : bbb00790.kgml
# Parse 817 st kgml file : lre00600.kgml
# Parse 818 st kgml file : lac01501.kgml
# Parse 819 st kgml file : lca00552.kgml
# Parse 820 st kgml file : lca00670.kgml
# Parse 821 st kgml file : lfe02060.kgml
# Parse 822 st kgml file : lfe00230.kgml
# Parse 823 st kgml file : lre02020.kgml
# Parse 824 st kgml file : lre00020.kgml
# Parse 825 st kgml file : lca00626.kgml
# Parse 826 st kgml file : lac00350.kgml
# Parse 827 st kgml file : lrh00564.kgml
# Parse 828 st kgml file : lac00030.kgml
# Parse 829 st kgml file : lca00860.kgml
# Parse 830 st kgml file : lpl00052.kgml
# Parse 831 st kgml file : lfe02024.kgml
# Parse 832 st kgml file : bbb00470.kgml
# Parse 833 st kgml file : lre01100.kgml
# Parse 834 st kgml file : lac00010.kgml
# Parse 835 st kgml file : lpl00300.kgml
# Parse 836 st kgml file : lre00860.kgml
# Parse 837 st kgml file : lcx03060.kgml
# Parse 838 st kgml file : bbb02020.kgml
# Parse 839 st kgml file : lfe00380.kgml
# Parse 840 st kgml file : lca00780.kgml
# Parse 841 st kgml file : lrh00660.kgml
# Parse 842 st kgml file : lpl00750.kgml
# Parse 843 st kgml file : lre02060.kgml
# Parse 844 st kgml file : lpl03070.kgml
# Parse 845 st kgml file : lre00360.kgml
# Parse 846 st kgml file : lre00760.kgml
# Parse 847 st kgml file : lac03010.kgml
# Parse 848 st kgml file : lca01100.kgml
# Parse 849 st kgml file : lac00220.kgml
# Parse 850 st kgml file : bcoa03440.kgml
# Parse 851 st kgml file : lpl00330.kgml
# Parse 852 st kgml file : lre00030.kgml
# Parse 853 st kgml file : lac00970.kgml
# Parse 854 st kgml file : lrh01250.kgml
# Parse 855 st kgml file : lca00480.kgml
# Parse 856 st kgml file : bcoa00240.kgml
# Parse 857 st kgml file : bbb00630.kgml
# Parse 858 st kgml file : lfe00521.kgml
# Parse 859 st kgml file : lre00621.kgml
# Parse 860 st kgml file : lca01200.kgml
# Parse 861 st kgml file : lac03020.kgml
# Parse 862 st kgml file : bbb00240.kgml
# Parse 863 st kgml file : lrh00622.kgml
# Parse 864 st kgml file : lac01220.kgml
# Parse 865 st kgml file : lac00330.kgml
# Parse 866 st kgml file : lfe00332.kgml
# Parse 867 st kgml file : lrh04122.kgml
# Parse 868 st kgml file : bcoa00999.kgml
# Parse 869 st kgml file : lre00230.kgml
# Parse 870 st kgml file : lrh00260.kgml
# Parse 871 st kgml file : lpl00590.kgml
# Parse 872 st kgml file : lfe00552.kgml
# Parse 873 st kgml file : bcoa00071.kgml
# Parse 874 st kgml file : lca00500.kgml
# Parse 875 st kgml file : lpl00564.kgml
# Parse 876 st kgml file : bbb01502.kgml
# Parse 877 st kgml file : lpl01120.kgml
# Parse 878 st kgml file : lre03410.kgml
# Parse 879 st kgml file : lpl03060.kgml
# Parse 880 st kgml file : lpl00010.kgml
# Parse 881 st kgml file : bcoa00970.kgml
# Parse 882 st kgml file : lre00280.kgml
# Parse 883 st kgml file : lcx00020.kgml
# Parse 884 st kgml file : lfe02010.kgml
# Parse 885 st kgml file : lre00300.kgml
# Parse 886 st kgml file : bcoa01210.kgml
# Parse 887 st kgml file : lrh00270.kgml
# Parse 888 st kgml file : lpl00626.kgml
# Parse 889 st kgml file : lpl00790.kgml
# Parse 890 st kgml file : lca00730.kgml
# Parse 891 st kgml file : lfe00350.kgml
# Parse 892 st kgml file : lca00910.kgml
# Parse 893 st kgml file : lfe00261.kgml
# Parse 894 st kgml file : bcoa00562.kgml
# Parse 895 st kgml file : bcoa00552.kgml
# Parse 896 st kgml file : lpl00440.kgml
# Parse 897 st kgml file : lrh00250.kgml
# Parse 898 st kgml file : lcx00999.kgml
# Parse 899 st kgml file : bcoa00730.kgml
# Parse 900 st kgml file : lcx00470.kgml
# Parse 901 st kgml file : lca00650.kgml
# Parse 902 st kgml file : lrh01220.kgml
# Parse 903 st kgml file : lfe00760.kgml
# Parse 904 st kgml file : lre00220.kgml
# Parse 905 st kgml file : lca01232.kgml
# Parse 906 st kgml file : lcx00362.kgml
# Parse 907 st kgml file : lcx00400.kgml
# Parse 908 st kgml file : lfe00052.kgml
# Parse 909 st kgml file : lfe00900.kgml
# Parse 910 st kgml file : lcx00670.kgml
# Parse 911 st kgml file : lre00670.kgml
# Parse 912 st kgml file : lcx00920.kgml
# Parse 913 st kgml file : lre03020.kgml
# Parse 914 st kgml file : lre01200.kgml
# Parse 915 st kgml file : lcx00190.kgml
# Parse 916 st kgml file : lac00460.kgml
# Parse 917 st kgml file : lrh00340.kgml
# Parse 918 st kgml file : lfe00790.kgml
# Parse 919 st kgml file : lfe00541.kgml
# Parse 920 st kgml file : bbb01250.kgml
# Parse 921 st kgml file : lpl00542.kgml
# Parse 922 st kgml file : lpl00561.kgml
# Parse 923 st kgml file : bbb00220.kgml
# Parse 924 st kgml file : bbb00515.kgml
# Parse 925 st kgml file : lac00790.kgml
# Parse 926 st kgml file : lac01230.kgml
# Parse 927 st kgml file : lac00261.kgml
# Parse 928 st kgml file : lca00643.kgml
# Parse 929 st kgml file : lac00450.kgml
# Parse 930 st kgml file : lpl00630.kgml
# Parse 931 st kgml file : lca00550.kgml
# Parse 932 st kgml file : lfe00626.kgml
# Parse 933 st kgml file : lpl00260.kgml

# %%
map_list = [x.split('.')[0] for x in kgml2com_dict.keys()]

# %%
component_dict
# Out:
# {'cpd:C03046': 17,
#  'cpd:C01769': 17,
#  'cpd:C00810': 25,
#  'cpd:C03044': 17,
#  'cpd:C06010': 70,
#  'cpd:C00022': 402,
#  'cpd:C00042': 162,
#  'cpd:C00122': 148,
#  'cpd:C01384': 44,
#  'cpd:C00497': 17,
#  'cpd:C02527': 17,
#  'cpd:C00246': 17,
#  'cpd:C00136': 79,
#  'cpd:C01412': 26,
#  'cpd:C00877': 100,
#  'cpd:C02411': 34,
#  'cpd:C03058': 17,
#  'cpd:C02630': 25,
#  'cpd:C00026': 189,
#  'cpd:C00024': 326,
#  'cpd:C00356': 44,
#  'cpd:C00332': 120,
#  'cpd:C00164': 67,
#  'cpd:C01089': 17,
#  'cpd:C04546': 17,
#  'cpd:C03561': 52,
#  'cpd:C01144': 99,
#  'cpd:C02331': 17,
#  'cpd:C06143': 17,
#  'cpd:C00989': 35,
#  'cpd:C00232': 79,
#  'cpd:C00334': 65,
#  'cpd:C00025': 218,
#  'cpd:C06142': 35,
#  'cpd:C06144': 17,
#  'cpd:C06145': 8,
#  'cpd:C06146': 8,
#  'cpd:C00741': 17,
#  'cpd:C11062': 35,
#  'cpd:C00091': 123,
#  'cpd:C20657': 17,
#  'cpd:C21390': 35,
#  'cpd:C00207': 17,
#  'cpd:C17530': 17,
#  'cpd:C00132': 53,
#  'cpd:C01845': 17,
#  'cpd:C20783': 17,
#  'cpd:C02656': 26,
#  'cpd:C01063': 52,
#  'cpd:C01092': 26,
#  'cpd:C01909': 26,
#  'cpd:C01037': 26,
#  'cpd:C00120': 44,
#  'cpd:C00047': 106,
#  'cpd:C05552': 17,
#  'cpd:C01894': 8,
#  'cpd:C05921': 17,
#  'cpd:C06250': 17,
#  'cpd:C19845': 26,
#  'cpd:C19846': 26,
#  'cpd:C01209': 80,
#  'cpd:C19673': 26,
#  'cpd:C20372': 26,
#  'cpd:C20373': 26,
#  'cpd:C20374': 26,
#  'cpd:C20375': 26,
#  'cpd:C20376': 26,
#  'cpd:C20377': 26,
#  'cpd:C20378': 26,
#  'cpd:C20683': 34,
#  'cpd:C20384': 8,
#  'cpd:C20385': 8,
#  'cpd:C20386': 17,
#  'cpd:C20387': 8,
#  'cpd:C00086': 80,
#  'cpd:C22458': 26,
#  'cpd:C20799': 17,
#  'cpd:C22416': 17,
#  'cpd:C22425': 17,
#  'cpd:C22455': 17,
#  'cpd:C00088': 82,
#  'cpd:C22388': 17,
#  'cpd:C16257': 8,
#  'cpd:C22466': 17,
#  'cpd:C06524': 8,
#  'cpd:C11242': 16,
#  'cpd:C21217': 16,
#  'cpd:C07276': 9,
#  'cpd:C07271': 9,
#  'cpd:C16462': 9,
#  'cpd:C04785': 18,
#  'cpd:C06427': 18,
#  'cpd:C09848': 8,
#  'cpd:C21301': 17,
#  'cpd:C21328': 17,
#  'cpd:C01241': 26,
#  'cpd:C00350': 26,
#  'cpd:C02737': 35,
#  'cpd:C19701': 17,
#  'cpd:C00988': 35,
#  'cpd:C01182': 53,
#  'cpd:C03506': 39,
#  'cpd:C00463': 44,
#  'cpd:C00978': 24,
#  'cpd:C00780': 24,
#  'cpd:C01598': 24,
#  'cpd:C02162': 14,
#  'cpd:C02951': 14,
#  'cpd:C01864': 14,
#  'cpd:C00841': 14,
#  'cpd:C22007': 14,
#  'cpd:C09265': 14,
#  'cpd:C09263': 14,
#  'cpd:C18080': 14,
#  'cpd:C18083': 14,
#  'cpd:C09060': 14,
#  'cpd:C19707': 14,
#  'cpd:C22152': 14,
#  'cpd:C01557': 14,
#  'cpd:C00758': 14,
#  'cpd:C09305': 14,
#  'cpd:C09276': 14,
#  'cpd:C04351': 17,
#  'cpd:C01575': 17,
#  'cpd:C16719': 17,
#  'cpd:C08301': 17,
#  'cpd:C17268': 17,
#  'cpd:C08797': 8,
#  'cpd:C08800': 8,
#  'cpd:C08795': 8,
#  'cpd:C22435': 8,
#  'cpd:C22434': 8,
#  'cpd:C22433': 8,
#  'cpd:C08794': 8,
#  'cpd:C08796': 8,
#  'cpd:C22437': 8,
#  'cpd:C22436': 8,
#  'cpd:C21841': 8,
#  'cpd:C22453': 26,
#  'cpd:C07544': 8,
#  'cpd:C07541': 8,
#  'cpd:C22432': 8,
#  'cpd:C06068': 8,
#  'cpd:C11382': 17,
#  'cpd:C05324': 32,
#  'cpd:C15502': 23,
#  'cpd:C15501': 23,
#  'cpd:C15500': 23,
#  'cpd:C15485': 23,
#  'cpd:C15486': 23,
#  'cpd:C04444': 8,
#  'cpd:C01265': 8,
#  'cpd:C04443': 8,
#  'cpd:C05855': 8,
#  'cpd:C15546': 8,
#  'cpd:C09666': 8,
#  'cpd:C06567': 9,
#  'cpd:C00916': 18,
#  'cpd:C22075': 17,
#  'cpd:C22074': 17,
#  'cpd:C03112': 18,
#  'cpd:C18062': 14,
#  'cpd:C15772': 14,
#  'cpd:C15770': 14,
#  'cpd:C04831': 14,
#  'cpd:C08544': 8,
#  'cpd:C17758': 8,
#  'cpd:C22430': 8,
#  'cpd:C05607': 25,
#  'cpd:C02066': 8,
#  'cpd:C15612': 8,
#  'cpd:C05177': 8,
#  'cpd:C16223': 8,
#  'cpd:C02134': 8,
#  'cpd:C16225': 8,
#  'cpd:C12125': 8,
#  'cpd:C08641': 8,
#  'cpd:C16354': 8,
#  'cpd:C16313': 8,
#  'cpd:C16312': 8,
#  'cpd:C12138': 8,
#  'cpd:C16299': 8,
#  'cpd:C12096': 8,
#  'cpd:C12095': 8,
#  'cpd:C08604': 8,
#  'cpd:C12647': 8,
#  'cpd:C12641': 8,
#  'cpd:C12640': 8,
#  'cpd:C16297': 8,
#  'cpd:C16490': 8,
#  'cpd:C12626': 8,
#  'cpd:C12667': 8,
#  'cpd:C11620': 8,
#  'cpd:C12633': 8,
#  'cpd:C12636': 8,
#  'cpd:C12635': 8,
#  'cpd:C12634': 8,
#  'cpd:C12249': 8,
#  'cpd:C16410': 8,
#  'cpd:C16408': 8,
#  'cpd:C16409': 8,
#  'cpd:C16407': 8,
#  'cpd:C15525': 17,
#  'cpd:C17750': 8,
#  'cpd:C17749': 8,
#  'cpd:C05627': 8,
#  'cpd:C02887': 8,
#  'cpd:C00933': 8,
#  'cpd:C01175': 8,
#  'cpd:C00761': 8,
#  'cpd:C10452': 8,
#  'cpd:C16930': 8,
#  'cpd:C10428': 8,
#  'cpd:C20464': 8,
#  'cpd:C20465': 8,
#  'cpd:C16464': 9,
#  'cpd:C19079': 9,
#  'cpd:C11937': 9,
#  'cpd:C11407': 18,
#  'cpd:C11405': 18,
#  'cpd:C11404': 18,
#  'cpd:C11402': 18,
#  'cpd:C11398': 18,
#  'cpd:C00147': 35,
#  'cpd:C19874': 8,
#  'cpd:C15514': 9,
#  'cpd:C15969': 9,
#  'cpd:C08584': 9,
#  'cpd:C08585': 9,
#  'cpd:C06089': 17,
#  'cpd:C11894': 17,
#  'cpd:C21735': 8,
#  'cpd:C21714': 8,
#  'cpd:C21656': 8,
#  'cpd:C20700': 8,
#  'cpd:C20681': 8,
#  'cpd:C21709': 8,
#  'cpd:C16341': 9,
#  'cpd:C22342': 17,
#  'cpd:C22341': 17,
#  'cpd:C22340': 17,
#  'cpd:C20518': 17,
#  'cpd:C20466': 17,
#  'cpd:C18059': 17,
#  'cpd:C04638': 17,
#  'cpd:C04590': 17,
#  'cpd:C00623': 17,
#  'cpd:C01935': 26,
#  'cpd:C00369': 26,
#  'cpd:C02463': 43,
#  'cpd:C05778': 43,
#  'cpd:C16280': 9,
#  'cpd:C16279': 9,
#  'cpd:C22346': 9,
#  'cpd:C15864': 9,
#  'cpd:C15861': 9,
#  'cpd:C15859': 9,
#  'cpd:C21770': 9,
#  'cpd:C19798': 9,
#  'cpd:C19797': 9,
#  'cpd:C15942': 9,
#  'cpd:C15941': 9,
#  'cpd:C15940': 9,
#  'cpd:C15917': 9,
#  'cpd:C15914': 9,
#  'cpd:C15911': 9,
#  'cpd:C15908': 9,
#  'cpd:C08607': 18,
#  'cpd:C19892': 18,
#  'cpd:C08613': 18,
#  'cpd:C15867': 18,
#  'cpd:C22349': 18,
#  'cpd:C22348': 18,
#  'cpd:C22347': 18,
#  'cpd:C22060': 18,
#  'cpd:C22059': 18,
#  'cpd:C22058': 18,
#  'cpd:C15888': 18,
#  'cpd:C15887': 18,
#  'cpd:C15886': 18,
#  'cpd:C15885': 18,
#  'cpd:C15884': 18,
#  'cpd:C15881': 18,
#  'cpd:C15879': 18,
#  'cpd:C15878': 18,
#  'cpd:C15877': 18,
#  'cpd:C15874': 18,
#  'cpd:C19795': 18,
#  'cpd:C16148': 9,
#  'cpd:C16147': 9,
#  'cpd:C16146': 9,
#  'cpd:C16145': 9,
#  'cpd:C16144': 9,
#  'cpd:C22339': 16,
#  'cpd:C22338': 16,
#  'cpd:C16695': 34,
#  'cpd:C17570': 34,
#  'cpd:C00390': 52,
#  'cpd:C00078': 82,
#  'cpd:C00398': 24,
#  'cpd:C15680': 17,
#  'cpd:C18847': 17,
#  'cpd:C18846': 17,
#  'cpd:C15681': 17,
#  'cpd:C15682': 17,
#  'cpd:C15683': 17,
#  'cpd:C15684': 17,
#  'cpd:C11853': 17,
#  'cpd:C02034': 17,
#  'cpd:C06095': 17,
#  'cpd:C06094': 17,
#  'cpd:C21425': 8,
#  'cpd:C20192': 8,
#  'cpd:C21979': 17,
#  'cpd:C21978': 17,
#  'cpd:C20834': 17,
#  'cpd:C16356': 17,
#  'cpd:C13747': 26,
#  'cpd:C05554': 26,
#  'cpd:C20333': 26,
#  'cpd:C03955': 26,
#  'cpd:C01028': 26,
#  'cpd:C22289': 17,
#  'cpd:C06454': 17,
#  'cpd:C06452': 17,
#  'cpd:C22217': 17,
#  'cpd:C22216': 17,
#  'cpd:C16755': 17,
#  'cpd:C06800': 17,
#  'cpd:C03686': 17,
#  'cpd:C00961': 17,
#  'cpd:C03683': 17,
#  'cpd:C20583': 17,
#  'cpd:C07712': 17,
#  'cpd:C01561': 17,
#  'cpd:C05443': 17,
#  'cpd:C01164': 17,
#  'cpd:C01189': 17,
#  'cpd:C03845': 17,
#  'cpd:C12433': 8,
#  'cpd:C20682': 41,
#  'cpd:C07277': 41,
#  'cpd:C01251': 71,
#  'cpd:C04002': 53,
#  'cpd:C05662': 62,
#  'cpd:C05560': 26,
#  'cpd:C05535': 26,
#  'cpd:C02074': 8,
#  'cpd:C20810': 17,
#  'cpd:C20921': 17,
#  'cpd:C20918': 17,
#  'cpd:C20917': 17,
#  'cpd:C20916': 17,
#  'cpd:C20915': 17,
#  'cpd:C20914': 17,
#  'cpd:C20913': 17,
#  'cpd:C20928': 17,
#  'cpd:C20929': 26,
#  'cpd:C00224': 71,
#  'cpd:C00059': 107,
#  'cpd:C06457': 9,
#  'cpd:C17951': 9,
#  'cpd:C04650': 9,
#  'cpd:C17952': 9,
#  'cpd:C17950': 9,
#  'cpd:C17949': 9,
#  'cpd:C17962': 9,
#  'cpd:C17948': 9,
#  'cpd:C21372': 9,
#  'cpd:C17947': 9,
#  'cpd:C06368': 9,
#  'cpd:C06367': 9,
#  'cpd:C17945': 9,
#  'cpd:C06456': 9,
#  'cpd:C17943': 9,
#  'cpd:C06455': 9,
#  'cpd:C06451': 18,
#  'cpd:C03167': 27,
#  'cpd:C02798': 27,
#  'cpd:C21439': 8,
#  'cpd:C09131': 8,
#  'cpd:C17585': 8,
#  'cpd:C04290': 8,
#  'cpd:C09023': 8,
#  'cpd:C20457': 8,
#  'cpd:C20438': 8,
#  'cpd:C20436': 8,
#  'cpd:C20437': 8,
#  'cpd:C20408': 8,
#  'cpd:C20409': 8,
#  'cpd:C21897': 8,
#  'cpd:C20379': 8,
#  'cpd:C20410': 8,
#  'cpd:C20509': 8,
#  'cpd:C12026': 8,
#  'cpd:C12325': 8,
#  'cpd:C12324': 8,
#  'cpd:C12395': 8,
#  'cpd:C18680': 8,
#  'cpd:C06799': 8,
#  'cpd:C18359': 8,
#  'cpd:C18835': 8,
#  'cpd:C18357': 8,
#  'cpd:C18355': 8,
#  'cpd:C00010': 91,
#  'cpd:C01134': 43,
#  'cpd:C00831': 34,
#  'cpd:C20445': 17,
#  'cpd:C20815': 16,
#  'cpd:C11755': 16,
#  'cpd:C17399': 16,
#  'cpd:C20816': 16,
#  'cpd:C20814': 16,
#  'cpd:C17373': 16,
#  'cpd:C17374': 16,
#  'cpd:C20813': 16,
#  'cpd:C17377': 16,
#  'cpd:C06664': 16,
#  'cpd:C20820': 16,
#  'cpd:C20819': 16,
#  'cpd:C20818': 16,
#  'cpd:C20817': 16,
#  'cpd:C07756': 9,
#  'cpd:C15666': 9,
#  'cpd:C04712': 9,
#  'cpd:C17954': 8,
#  'cpd:C17953 cpd:C17955': 8,
#  'cpd:C19691': 17,
#  'cpd:C04748': 17,
#  'cpd:C04506': 17,
#  'cpd:C20120': 17,
#  'cpd:C03461': 17,
#  'cpd:C05441': 17,
#  'cpd:C01694': 17,
#  'cpd:C05440': 17,
#  'cpd:C04525': 17,
#  'cpd:C05437': 17,
#  'cpd:C22136': 17,
#  'cpd:C22112': 17,
#  'cpd:C05103': 17,
#  'cpd:C15816': 17,
#  'cpd:C15808': 17,
#  'cpd:C05108': 17,
#  'cpd:C11455': 17,
#  'cpd:C01054': 23,
#  'cpd:C10107': 8,
#  'cpd:C00389': 17,
#  'cpd:C05903': 17,
#  'cpd:C00814': 17,
#  'cpd:C06563': 17,
#  'cpd:C14463': 26,
#  'cpd:C06007': 44,
#  'cpd:C05777': 43,
#  'cpd:C21512': 43,
#  'cpd:C21511': 43,
#  'cpd:C21510': 43,
#  'cpd:C00748': 34,
#  'cpd:C21357': 17,
#  'cpd:C20668': 17,
#  'cpd:C22102': 17,
#  'cpd:C22101': 17,
#  'cpd:C00515': 26,
#  'cpd:C20962 cpd:C20963 cpd:C20964': 17,
#  'cpd:C20966': 17,
#  'cpd:C20961': 17,
#  'cpd:C22072': 17,
#  'cpd:C03401': 17,
#  'cpd:C05770': 34,
#  'cpd:C22073': 17,
#  'cpd:C21559': 17,
#  'cpd:C21093': 17,
#  'cpd:C19814': 17,
#  'cpd:C19815': 17,
#  'cpd:C19939': 17,
#  'cpd:C01841': 17,
#  'cpd:C20402': 8,
#  'cpd:C20405': 8,
#  'cpd:C20407': 17,
#  'cpd:C20397': 17,
#  'cpd:C20399': 17,
#  'cpd:C20400': 17,
#  'cpd:C20403': 17,
#  'cpd:C20404': 17,
#  'cpd:C01610': 17,
#  'cpd:C07032': 17,
#  'cpd:C07031': 17,
#  'cpd:C07030': 17,
#  'cpd:C07029': 17,
#  'cpd:C07028': 17,
#  'cpd:C07027': 17,
#  'cpd:C07026': 17,
#  'cpd:C07025': 17,
#  'cpd:C07024': 17,
#  'cpd:C21875': 17,
#  'cpd:C21874': 17,
#  'cpd:C21140': 17,
#  'cpd:C21141': 17,
#  'cpd:C21330': 17,
#  'cpd:C10641': 17,
#  'cpd:C22142': 17,
#  'cpd:C19687': 17,
#  'cpd:C16518': 33,
#  'cpd:C02937': 33,
#  'cpd:C21124': 17,
#  'cpd:C18092': 17,
#  'cpd:C19700': 17,
#  'cpd:C19699': 17,
#  'cpd:C19698': 17,
#  'cpd:C19688': 17,
#  'cpd:C21136': 17,
#  'cpd:C21135': 17,
#  'cpd:C21134': 17,
#  'cpd:C21131': 17,
#  'cpd:C02079': 17,
#  'cpd:C07349': 17,
#  'cpd:C21128': 17,
#  'cpd:C21127': 17,
#  'cpd:C21126': 17,
#  'cpd:C21125': 17,
#  'cpd:C21630': 8,
#  'cpd:C05769': 25,
#  'cpd:C05767': 16,
#  'cpd:C04272': 53,
#  'cpd:C04181': 26,
#  'cpd:C22170': 8,
#  'cpd:C22172': 8,
#  'cpd:C22171': 8,
#  'cpd:C22169': 8,
#  'cpd:C22163': 8,
#  'cpd:C22168': 8,
#  'cpd:C22167': 8,
#  'cpd:C22166': 8,
#  'cpd:C22165': 8,
#  'cpd:C22164': 8,
#  'cpd:C22162': 8,
#  'cpd:C09244': 17,
#  'cpd:C11642': 8,
#  'cpd:C11643': 8,
#  'cpd:C11677': 8,
#  'cpd:C21368': 22,
#  'cpd:C21367': 13,
#  'cpd:C21415': 13,
#  'cpd:C17699': 13,
#  'cpd:C21249': 13,
#  'cpd:C21248': 13,
#  'cpd:C21247': 13,
#  'cpd:C17695': 13,
#  'cpd:C17698': 13,
#  'cpd:C21211': 13,
#  'cpd:C21210': 13,
#  'cpd:C21209': 13,
#  'cpd:C21293': 13,
#  'cpd:C12112': 22,
#  'cpd:C17700': 22,
#  'cpd:C21218': 22,
#  'cpd:C21216': 22,
#  'cpd:C21219': 22,
#  'cpd:C17697': 22,
#  'cpd:C17696': 22,
#  'cpd:C17694': 22,
#  'cpd:C06802': 22,
#  'cpd:C21156': 22,
#  'cpd:C21208': 22,
#  'cpd:C21207': 22,
#  'cpd:C21206': 22,
#  'cpd:C21205': 22,
#  'cpd:C21204': 22,
#  'cpd:C17693': 22,
#  'cpd:C17692': 22,
#  'cpd:C17691': 22,
#  'cpd:C20956': 22,
#  'cpd:C00180': 70,
#  'cpd:C12312': 14,
#  'cpd:C00483': 44,
#  'cpd:C03758': 26,
#  'cpd:C16707': 8,
#  'cpd:C12457': 12,
#  'cpd:C12458': 12,
#  'cpd:C12459': 12,
#  'cpd:C12460': 12,
#  'cpd:C12456': 12,
#  'cpd:C12483': 34,
#  'cpd:C12032': 12,
#  'cpd:C12473': 12,
#  'cpd:C12472': 12,
#  'cpd:C12471': 12,
#  'cpd:C12469': 12,
#  'cpd:C05073': 12,
#  'cpd:C12480': 12,
#  'cpd:C12479': 12,
#  'cpd:C20637': 12,
#  'cpd:C12477': 12,
#  'cpd:C05080': 21,
#  'cpd:C12476': 21,
#  'cpd:C12475': 21,
#  'cpd:C12474': 21,
#  'cpd:C20629': 21,
#  'cpd:C12468': 21,
#  'cpd:C12467': 21,
#  'cpd:C12463': 21,
#  'cpd:C12462': 21,
#  'cpd:C12461': 21,
#  'cpd:C02916': 8,
#  'cpd:C20982': 8,
#  'cpd:C01748': 17,
#  'cpd:C21442': 17,
#  'cpd:C21477': 8,
#  'cpd:C21295': 17,
#  'cpd:C20981': 17,
#  'cpd:C21412': 17,
#  'cpd:C12119': 8,
#  'cpd:C21474': 8,
#  'cpd:C21410': 8,
#  'cpd:C21409': 8,
#  'cpd:C21476': 8,
#  'cpd:C21475': 8,
#  'cpd:C21413': 8,
#  'cpd:C21411': 17,
#  'cpd:C21408': 17,
#  'cpd:C21473': 17,
#  'cpd:C19831': 17,
#  'cpd:C19830': 17,
#  'cpd:C01944': 52,
#  'cpd:C11848': 17,
#  'cpd:C20643': 17,
#  'cpd:C21490': 8,
#  'cpd:C21453': 8,
#  'cpd:C21452': 8,
#  'cpd:C21488': 8,
#  'cpd:C12023': 17,
#  'cpd:C21574': 17,
#  'cpd:C21573': 17,
#  'cpd:C02679': 35,
#  'cpd:C09727': 17,
#  'cpd:C05905': 17,
#  'cpd:C21565': 17,
#  'cpd:C21572': 17,
#  'cpd:C21571': 17,
#  'cpd:C21139': 17,
#  'cpd:C21138': 17,
#  'cpd:C21570': 17,
#  'cpd:C21569': 17,
#  'cpd:C21568': 17,
#  'cpd:C21567': 17,
#  'cpd:C12470': 21,
#  'cpd:C16753': 17,
#  'cpd:C03944': 17,
#  'cpd:C16754': 17,
#  'cpd:C09315': 14,
#  'cpd:C20508': 8,
#  'cpd:C20506': 8,
#  'cpd:C20504': 8,
#  'cpd:C20501': 8,
#  'cpd:C20444': 17,
#  'cpd:C20575': 17,
#  'cpd:C20507': 17,
#  'cpd:C20505': 17,
#  'cpd:C20503': 17,
#  'cpd:C20574': 17,
#  'cpd:C20502': 17,
#  'cpd:C20500': 17,
#  'cpd:C20499': 17,
#  'cpd:C20452': 17,
#  'cpd:C20453': 17,
#  'cpd:C01823': 8,
#  'cpd:C01743': 8,
#  'cpd:C20699': 8,
#  'cpd:C01822': 8,
#  'cpd:C21251': 8,
#  'cpd:C20614': 8,
#  'cpd:C21253': 8,
#  'cpd:C20350': 8,
#  'cpd:C20351': 8,
#  'cpd:C20353': 8,
#  'cpd:C18000': 8,
#  'cpd:C00825': 8,
#  'cpd:C21252': 8,
#  'cpd:C18003': 8,
#  'cpd:C21264': 8,
#  'cpd:C00832': 8,
#  'cpd:C17712': 8,
#  'cpd:C21263': 8,
#  'cpd:C21262': 8,
#  'cpd:C21261': 8,
#  'cpd:C18002': 8,
#  'cpd:C21260': 8,
#  'cpd:C01737': 8,
#  'cpd:C15652': 8,
#  'cpd:C17589': 8,
#  'cpd:C17588': 8,
#  'cpd:C17587': 8,
#  'cpd:C18009': 8,
#  'cpd:C18008': 8,
#  'cpd:C18007': 8,
#  'cpd:C17586': 8,
#  'cpd:C18005': 8,
#  'cpd:C21258': 8,
#  'cpd:C18001': 8,
#  'cpd:C00397': 8,
#  'cpd:C21259': 8,
#  'cpd:C21256': 8,
#  'cpd:C21255': 8,
#  'cpd:C21257': 8,
#  'cpd:C17584': 8,
#  'cpd:C21176': 8,
#  'cpd:C01759': 8,
#  'cpd:C18004': 8,
#  'cpd:C01441': 8,
#  'cpd:C17583': 8,
#  'cpd:C17701': 8,
#  'cpd:C17582': 8,
#  'cpd:C02627': 8,
#  'cpd:C17581': 8,
#  'cpd:C17580': 8,
#  'cpd:C17209': 8,
#  'cpd:C12014': 17,
#  'cpd:C12321': 26,
#  'cpd:C06689': 26,
#  'cpd:C12322': 26,
#  'cpd:C12320': 26,
#  'cpd:C12319': 26,
#  'cpd:C21327': 17,
#  'cpd:C21326': 17,
#  'cpd:C21325': 17,
#  'cpd:C21324': 17,
#  'cpd:C21323': 17,
#  'cpd:C21322': 17,
#  'cpd:C21321': 17,
#  'cpd:C21320': 17,
#  'cpd:C11469': 17,
#  'cpd:C21342': 17,
#  'cpd:C21341': 17,
#  'cpd:C21340': 17,
#  'cpd:C21339': 17,
#  'cpd:C21338': 17,
#  'cpd:C21337': 17,
#  'cpd:C21347': 17,
#  'cpd:C21346': 17,
#  'cpd:C21345': 17,
#  'cpd:C21344': 17,
#  'cpd:C21343': 17,
#  'cpd:C20345': 26,
#  'cpd:C20877': 18,
#  'cpd:C20876': 18,
#  'cpd:C20878': 18,
#  'cpd:C20856': 17,
#  'cpd:C12049': 17,
#  'cpd:C20842': 17,
#  'cpd:C20841': 17,
#  'cpd:C20857': 17,
#  'cpd:C21319': 8,
#  'cpd:C21318': 8,
#  'cpd:C21317': 8,
#  'cpd:C21316': 8,
#  'cpd:C21315': 8,
#  'cpd:C21314': 8,
#  'cpd:C21361': 8,
#  'cpd:C21311': 17,
#  'cpd:C07204': 8,
#  'cpd:C21292': 17,
#  'cpd:C21313': 17,
#  'cpd:C21312': 17,
#  'cpd:C02657': 17,
#  'cpd:C21308': 17,
#  'cpd:C11442': 8,
#  'cpd:C11438': 17,
#  'cpd:C11449': 17,
#  'cpd:C21309': 17,
#  'cpd:C11448': 17,
#  'cpd:C11468': 17,
#  'cpd:C21307': 17,
#  'cpd:C21306': 17,
#  'cpd:C19686': 17,
#  'cpd:C18054': 17,
#  'cpd:C21358': 8,
#  'cpd:C03069': 27,
#  'cpd:C16471': 9,
#  'cpd:C16469': 9,
#  'cpd:C16468': 9,
#  'cpd:C16470': 9,
#  'cpd:C16466': 9,
#  'cpd:C04675': 9,
#  'cpd:C01291': 9,
#  'cpd:C01920': 9,
#  'cpd:C16465': 9,
#  'cpd:C16461': 9,
#  'cpd:C12380': 8,
#  'cpd:C06801': 17,
#  'cpd:C12371': 17,
#  'cpd:C12370': 17,
#  'cpd:C12381': 17,
#  'cpd:C20977': 17,
#  'cpd:C20976': 17,
#  'cpd:C20975': 17,
#  'cpd:C20974': 17,
#  'cpd:C12379': 17,
#  'cpd:C12378': 17,
#  'cpd:C12369': 17,
#  'cpd:C12368': 17,
#  'cpd:C12367': 17,
#  'cpd:C12366': 17,
#  'cpd:C12389': 17,
#  'cpd:C18711': 17,
#  'cpd:C12388': 17,
#  'cpd:C18710': 17,
#  'cpd:C12387': 17,
#  'cpd:C12386': 17,
#  'cpd:C12385': 17,
#  'cpd:C12384': 17,
#  'cpd:C12383': 17,
#  'cpd:C12382': 17,
#  'cpd:C18709': 17,
#  'cpd:C18642': 8,
#  'cpd:C18641': 8,
#  'cpd:C18640': 8,
#  'cpd:C20689': 8,
#  'cpd:C18639': 8,
#  'cpd:C18638': 8,
#  'cpd:C18637': 8,
#  'cpd:C18635': 8,
#  'cpd:C18634': 8,
#  'cpd:C12432': 8,
#  'cpd:C12431': 8,
#  'cpd:C01661': 8,
#  'cpd:C01907': 8,
#  'cpd:C12430': 8,
#  'cpd:C12429': 8,
#  'cpd:C12428': 8,
#  'cpd:C12427': 8,
#  'cpd:C12426': 8,
#  'cpd:C12425': 8,
#  'cpd:C12424': 17,
#  'cpd:C12423': 17,
#  'cpd:C12422': 17,
#  'cpd:C12421': 17,
#  'cpd:C12420': 17,
#  'cpd:C12409': 8,
#  'cpd:C12407': 8,
#  'cpd:C18633': 8,
#  'cpd:C05442': 17,
#  'cpd:C12406': 8,
#  'cpd:C12405': 8,
#  'cpd:C12413': 8,
#  'cpd:C12414': 8,
#  'cpd:C12408': 8,
#  'cpd:C12412': 8,
#  'cpd:C12410': 8,
#  'cpd:C18681': 8,
#  'cpd:C12397': 8,
#  'cpd:C12396': 8,
#  'cpd:C18679': 8,
#  'cpd:C18685': 8,
#  'cpd:C18684': 8,
#  'cpd:C18778': 8,
#  'cpd:C18683': 8,
#  'cpd:C18682': 8,
#  'cpd:C12402': 8,
#  'cpd:C18678': 8,
#  'cpd:C12419': 8,
#  'cpd:C12417': 8,
#  'cpd:C18632': 8,
#  'cpd:C18631': 17,
#  'cpd:C18630': 17,
#  'cpd:C12415': 17,
#  'cpd:C12416': 17,
#  'cpd:C18629': 17,
#  'cpd:C06624': 17,
#  'cpd:C18296': 17,
#  'cpd:C06571': 17,
#  'cpd:C06570': 17,
#  'cpd:C03206': 17,
#  'cpd:C02811': 17,
#  'cpd:C06654': 17,
#  'cpd:C06627': 17,
#  'cpd:C06628': 17,
#  'cpd:C06629': 17,
#  'cpd:C18295': 17,
#  'cpd:C18294': 17,
#  'cpd:C06691': 8,
#  'cpd:C18358': 8,
#  'cpd:C18360': 8,
#  'cpd:C12436': 17,
#  'cpd:C12435': 17,
#  'cpd:C12434': 17,
#  'cpd:C18356': 17,
#  'cpd:C18354': 17,
#  'cpd:C18353': 17,
#  'cpd:C18337': 17,
#  'cpd:C18336': 17,
#  'cpd:C18333': 17,
#  'cpd:C18330': 17,
#  'cpd:C18293': 17,
#  'cpd:C12442': 17,
#  'cpd:C18329': 17,
#  'cpd:C18328': 17,
#  'cpd:C21818': 8,
#  'cpd:C21796': 8,
#  'cpd:C14540': 8,
#  'cpd:C14723': 8,
#  'cpd:C14722': 8,
#  'cpd:C12044': 8,
#  'cpd:C14727': 8,
#  'cpd:C14725': 8,
#  'cpd:C14724': 8,
#  'cpd:C12247': 8,
#  'cpd:C14721': 8,
#  'cpd:C12176': 8,
#  'cpd:C12045': 8,
#  'cpd:C20140': 8,
#  'cpd:C20139': 8,
#  'cpd:C20138': 8,
#  'cpd:C20137': 8,
#  'cpd:C20136': 8,
#  'cpd:C20135': 8,
#  'cpd:C20134': 8,
#  'cpd:C12177': 8,
#  'cpd:C12107': 8,
#  'cpd:C12108': 8,
#  'cpd:C12109': 8,
#  'cpd:C12106': 8,
#  'cpd:C12213': 17,
#  'cpd:C12212': 17,
#  'cpd:C12211': 17,
#  'cpd:C12210': 17,
#  'cpd:C00683': 62,
#  'cpd:C11968': 17,
#  'cpd:C11966': 17,
#  'cpd:C11964': 17,
#  'cpd:C11967': 17,
#  'cpd:C11965': 17,
#  'cpd:C11963': 17,
#  'cpd:C11962': 17,
#  'cpd:C11961': 17,
#  'cpd:C08426': 17,
#  'cpd:C01033': 17,
#  'cpd:C11984': 17,
#  'cpd:C11982': 17,
#  'cpd:C11980': 17,
#  'cpd:C11983': 17,
#  'cpd:C11981': 17,
#  'cpd:C11979': 17,
#  'cpd:C11978': 17,
#  'cpd:C11977': 17,
#  'cpd:C20741': 8,
#  'cpd:C11996': 17,
#  'cpd:C11995': 8,
#  'cpd:C11994': 17,
#  'cpd:C11993': 17,
#  'cpd:C20739': 8,
#  'cpd:C11999': 17,
#  'cpd:C20740': 8,
#  'cpd:C11998': 17,
#  'cpd:C19819': 8,
#  'cpd:C19829': 14,
#  'cpd:C08628': 8,
#  'cpd:C11997': 17,
#  'cpd:C11986': 8,
#  'cpd:C11988': 8,
#  'cpd:C11987': 8,
#  'cpd:C11985': 8,
#  'cpd:C01912': 17,
#  'cpd:C06653': 17,
#  'cpd:C06616': 17,
#  'cpd:C06633': 17,
#  'cpd:C06630': 17,
#  'cpd:C06635': 17,
#  'cpd:C01946': 26,
#  'cpd:C11992': 17,
#  'cpd:C11991': 17,
#  'cpd:C11990': 17,
#  'cpd:C11989': 17,
#  'cpd:C02557': 17,
#  'cpd:C01457': 17,
#  'cpd:C00744': 17,
#  'cpd:C02400': 17,
#  'cpd:C12003': 17,
#  'cpd:C12002': 17,
#  'cpd:C20760': 17,
#  'cpd:C12001': 17,
#  'cpd:C12000': 17,
#  'cpd:C00100': 88,
#  'cpd:C03442': 34,
#  'cpd:C06620': 32,
#  'cpd:C11918': 14,
#  'cpd:C11921': 32,
#  'cpd:C21349': 14,
#  'cpd:C11916': 32,
#  'cpd:C11915': 32,
#  'cpd:C18035': 32,
#  'cpd:C21071': 32,
#  'cpd:C11927': 32,
#  'cpd:C11928': 32,
#  'cpd:C18033': 32,
#  'cpd:C18032': 32,
#  'cpd:C11922': 32,
#  'cpd:C18034': 32,
#  'cpd:C11920': 32,
#  'cpd:C18031': 32,
#  'cpd:C18030': 32,
#  'cpd:C18029': 32,
#  ...}
